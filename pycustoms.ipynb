# %%
# %pprint
# Out:
# Pretty printing has been turned OFF

# %%
  
def pycustoms(pkg_name, package_dictionary=None): 
    """
    pycustoms inspects packages, walking down '.' module hierarchies and finding
    methods, functions, classes, builtins, and none-of-the-above (aka nofta)
    
    Input: Package name as a string, imports it if it exists, exits if it doesn't    
     
    Returns: A dictionary:
    - keys are <module name>-methods, functions, classes, builtins, or nofta
    - values are the names of the methods, functions, classes, builtins, or nofta
    
    pycustoms ignores values prefixed with _ or __
    
    Some modules exist, can be inspected with dir(), but cannot be imported via
    the importlib.import_module.  pycustoms reports this and continues
    
    Usage: Enter at any level of a hierarchy
    
    ans = pycustoms('numpy.random')  # Explore a numpy submodule
    
    for key in sorted(ans.iterkeys()):  # Print the dictionary
        print "{}:\\n {} \\n".format(key,ans[key])   
        
    --> Large output
    
    Ravi Narasimhan  22 May 2017
    
    """
    
    import inspect
    import importlib
    import sys
 
    try:
        pkg = importlib.import_module(pkg_name)
    except ImportError:
        print "Can't find that one.  Stopping"
        sys.exit(1)
    
    modules = []
    functions = []
    classes = []
    builtins = []
    noneoftheabove = []
    if not package_dictionary:
        pkg_dict={}  # Create an empty dict if no dictionary is passed
    else:
        pkg_dict = package_dictionary
    for j in dir(pkg):
        if inspect.ismodule(getattr(pkg,j)):
            modules.append(j)
        elif inspect.isfunction((getattr(pkg,j))):
             functions.append(j)
        elif inspect.isclass((getattr(pkg,j))):
             classes.append(j)
        elif inspect.isbuiltin((getattr(pkg,j))):
             builtins.append(j)
        else:
             noneoftheabove.append(j)

    pkg_dict[pkg_name+'-'+'builtins'] = builtins
    pkg_dict[pkg_name+'-'+'modules'] = modules
    pkg_dict[pkg_name+'-'+'classes'] = classes
    pkg_dict[pkg_name+'-'+'functions'] = functions
    pkg_dict[pkg_name+'-'+'nofta'] = noneoftheabove
   
    for k in modules:
        if not k.startswith('_'):
            try:
                pkg = importlib.import_module(pkg_name+'.'+k)
            except ImportError:                
                pkg_dict[pkg_name+'.'+k] = 'This exists but I cannot inspect it'
                continue        
            pycustoms(pkg_name+'.'+k, pkg_dict)

    return pkg_dict

# %%
ans = pycustoms('numpy')

# %%
for key in sorted(ans.iterkeys()):
    print "{}:\n {} \n".format(key,ans[key])
# Out:
# numpy-builtins:
#  ['add_docstring', 'add_newdoc_ufunc', 'arange', 'array', 'bincount', 'busday_count', 'busday_offset', 'can_cast', 'compare_chararrays', 'concatenate', 'copyto', 'count_nonzero', 'datetime_as_string', 'datetime_data', 'digitize', 'dot', 'einsum', 'empty', 'empty_like', 'fastCopyAndTranspose', 'frombuffer', 'fromfile', 'fromiter', 'frompyfunc', 'fromstring', 'getbuffer', 'geterrobj', 'inner', 'int_asbuffer', 'is_busday', 'lexsort', 'loads', 'matmul', 'may_share_memory', 'min_scalar_type', 'nested_iters', 'newbuffer', 'packbits', 'promote_types', 'putmask', 'ravel_multi_index', 'result_type', 'set_numeric_ops', 'seterrobj', 'shares_memory', 'unpackbits', 'unravel_index', 'vdot', 'where', 'zeros']
#
# numpy-classes:
#  ['ComplexWarning', 'DataSource', 'MachAr', 'ModuleDeprecationWarning', 'PackageLoader', 'RankWarning', 'Tester', 'TooHardError', 'VisibleDeprecationWarning', '_NoValue', 'bool', 'bool8', 'bool_', 'broadcast', 'busdaycalendar', 'byte', 'bytes_', 'cdouble', 'cfloat', 'character', 'chararray', 'clongdouble', 'clongfloat', 'complex', 'complex128', 'complex256', 'complex64', 'complex_', 'complexfloating', 'csingle', 'datetime64', 'double', 'dtype', 'errstate', 'finfo', 'flatiter', 'flexible', 'float', 'float128', 'float16', 'float32', 'float64', 'float_', 'floating', 'format_parser', 'generic', 'half', 'iinfo', 'inexact', 'int', 'int0', 'int16', 'int32', 'int64', 'int8', 'int_', 'intc', 'integer', 'intp', 'long', 'longcomplex', 'longdouble', 'longfloat', 'longlong', 'matrix', 'memmap', 'ndarray', 'ndenumerate', 'ndindex', 'nditer', 'number', 'object', 'object0', 'object_', 'poly1d', 'recarray', 'record', 'short', 'signedinteger', 'single', 'singlecomplex', 'str', 'str_', 'string0', 'string_', 'timedelta64', 'ubyte', 'ufunc', 'uint', 'uint0', 'uint16', 'uint32', 'uint64', 'uint8', 'uintc', 'uintp', 'ulonglong', 'unicode', 'unicode0', 'unicode_', 'unsignedinteger', 'ushort', 'vectorize', 'void', 'void0']
#
# numpy-functions:
#  ['add_newdoc', 'alen', 'all', 'allclose', 'alltrue', 'alterdot', 'amax', 'amin', 'angle', 'any', 'append', 'apply_along_axis', 'apply_over_axes', 'argmax', 'argmin', 'argpartition', 'argsort', 'argwhere', 'around', 'array2string', 'array_equal', 'array_equiv', 'array_repr', 'array_split', 'array_str', 'asanyarray', 'asarray', 'asarray_chkfinite', 'ascontiguousarray', 'asfarray', 'asfortranarray', 'asmatrix', 'asscalar', 'atleast_1d', 'atleast_2d', 'atleast_3d', 'average', 'bartlett', 'base_repr', 'binary_repr', 'blackman', 'bmat', 'broadcast_arrays', 'broadcast_to', 'byte_bounds', 'choose', 'clip', 'column_stack', 'common_type', 'compress', 'convolve', 'copy', 'corrcoef', 'correlate', 'cov', 'cross', 'cumprod', 'cumproduct', 'cumsum', 'delete', 'deprecate', 'deprecate_with_doc', 'diag', 'diag_indices', 'diag_indices_from', 'diagflat', 'diagonal', 'diff', 'disp', 'dsplit', 'dstack', 'ediff1d', 'expand_dims', 'extract', 'eye', 'fill_diagonal', 'find_common_type', 'fix', 'flatnonzero', 'fliplr', 'flipud', 'fromfunction', 'fromregex', 'full', 'full_like', 'fv', 'genfromtxt', 'get_array_wrap', 'get_include', 'get_printoptions', 'getbufsize', 'geterr', 'geterrcall', 'gradient', 'hamming', 'hanning', 'histogram', 'histogram2d', 'histogramdd', 'hsplit', 'hstack', 'i0', 'identity', 'imag', 'in1d', 'indices', 'info', 'insert', 'interp', 'intersect1d', 'ipmt', 'irr', 'isclose', 'iscomplex', 'iscomplexobj', 'isfortran', 'isneginf', 'isposinf', 'isreal', 'isrealobj', 'isscalar', 'issctype', 'issubclass_', 'issubdtype', 'issubsctype', 'iterable', 'ix_', 'kaiser', 'kron', 'linspace', 'load', 'loadtxt', 'logspace', 'lookfor', 'mafromtxt', 'mask_indices', 'mat', 'max', 'maximum_sctype', 'mean', 'median', 'meshgrid', 'min', 'mintypecode', 'mirr', 'moveaxis', 'msort', 'nan_to_num', 'nanargmax', 'nanargmin', 'nanmax', 'nanmean', 'nanmedian', 'nanmin', 'nanpercentile', 'nanprod', 'nanstd', 'nansum', 'nanvar', 'ndfromtxt', 'ndim', 'nonzero', 'nper', 'npv', 'obj2sctype', 'ones', 'ones_like', 'outer', 'pad', 'partition', 'percentile', 'piecewise', 'pkgload', 'place', 'pmt', 'poly', 'polyadd', 'polyder', 'polydiv', 'polyfit', 'polyint', 'polymul', 'polysub', 'polyval', 'ppmt', 'prod', 'product', 'ptp', 'put', 'pv', 'rank', 'rate', 'ravel', 'real', 'real_if_close', 'recfromcsv', 'recfromtxt', 'repeat', 'require', 'reshape', 'resize', 'restoredot', 'roll', 'rollaxis', 'roots', 'rot90', 'round', 'round_', 'row_stack', 'safe_eval', 'save', 'savetxt', 'savez', 'savez_compressed', 'sctype2char', 'searchsorted', 'select', 'set_printoptions', 'set_string_function', 'setbufsize', 'setdiff1d', 'seterr', 'seterrcall', 'setxor1d', 'shape', 'show_config', 'sinc', 'size', 'sometrue', 'sort', 'sort_complex', 'source', 'split', 'squeeze', 'stack', 'std', 'sum', 'swapaxes', 'take', 'tensordot', 'tile', 'trace', 'transpose', 'trapz', 'tri', 'tril', 'tril_indices', 'tril_indices_from', 'trim_zeros', 'triu', 'triu_indices', 'triu_indices_from', 'typename', 'union1d', 'unique', 'unwrap', 'vander', 'var', 'vsplit', 'vstack', 'who', 'zeros_like']
#
# numpy-modules:
#  ['__config__', '_globals', '_import_tools', '_mat', 'add_newdocs', 'char', 'compat', 'core', 'ctypeslib', 'emath', 'fft', 'lib', 'linalg', 'ma', 'math', 'matrixlib', 'polynomial', 'random', 'rec', 'testing', 'version', 'warnings']
#
# numpy-nofta:
#  ['ALLOW_THREADS', 'BUFSIZE', 'CLIP', 'ERR_CALL', 'ERR_DEFAULT', 'ERR_IGNORE', 'ERR_LOG', 'ERR_PRINT', 'ERR_RAISE', 'ERR_WARN', 'FLOATING_POINT_SUPPORT', 'FPE_DIVIDEBYZERO', 'FPE_INVALID', 'FPE_OVERFLOW', 'FPE_UNDERFLOW', 'False_', 'Inf', 'Infinity', 'MAXDIMS', 'MAY_SHARE_BOUNDS', 'MAY_SHARE_EXACT', 'NAN', 'NINF', 'NZERO', 'NaN', 'PINF', 'PZERO', 'RAISE', 'SHIFT_DIVIDEBYZERO', 'SHIFT_INVALID', 'SHIFT_OVERFLOW', 'SHIFT_UNDERFLOW', 'ScalarType', 'True_', 'UFUNC_BUFSIZE_DEFAULT', 'UFUNC_PYVALS_NAME', 'WRAP', '__NUMPY_SETUP__', '__all__', '__builtins__', '__doc__', '__file__', '__git_revision__', '__mkl_version__', '__name__', '__package__', '__path__', '__version__', 'abs', 'absolute', 'absolute_import', 'add', 'arccos', 'arccosh', 'arcsin', 'arcsinh', 'arctan', 'arctan2', 'arctanh', 'bench', 'bitwise_and', 'bitwise_not', 'bitwise_or', 'bitwise_xor', 'c_', 'cast', 'cbrt', 'ceil', 'conj', 'conjugate', 'copysign', 'cos', 'cosh', 'deg2rad', 'degrees', 'divide', 'division', 'e', 'equal', 'euler_gamma', 'exp', 'exp2', 'expm1', 'fabs', 'floor', 'floor_divide', 'fmax', 'fmin', 'fmod', 'frexp', 'greater', 'greater_equal', 'hypot', 'index_exp', 'inf', 'infty', 'invert', 'isfinite', 'isinf', 'isnan', 'ldexp', 'left_shift', 'less', 'less_equal', 'little_endian', 'log', 'log10', 'log1p', 'log2', 'logaddexp', 'logaddexp2', 'logical_and', 'logical_not', 'logical_or', 'logical_xor', 'maximum', 'mgrid', 'minimum', 'mod', 'modf', 'multiply', 'nan', 'nbytes', 'negative', 'newaxis', 'nextafter', 'not_equal', 'numarray', 'ogrid', 'oldnumeric', 'pi', 'power', 'print_function', 'r_', 'rad2deg', 'radians', 'reciprocal', 'remainder', 'right_shift', 'rint', 's_', 'sctypeDict', 'sctypeNA', 'sctypes', 'sign', 'signbit', 'sin', 'sinh', 'spacing', 'sqrt', 'square', 'subtract', 'tan', 'tanh', 'test', 'true_divide', 'trunc', 'typeDict', 'typeNA', 'typecodes']
#
# numpy.add_newdocs-builtins:
#  []
#
# numpy.add_newdocs-classes:
#  []
#
# numpy.add_newdocs-functions:
#  ['add_newdoc']
#
# numpy.add_newdocs-modules:
#  []
#
# numpy.add_newdocs-nofta:
#  ['__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'print_function', 'tobytesdoc']
#
# numpy.char:
#  This exists but I cannot inspect it
#
# numpy.compat-builtins:
#  []
#
# numpy.compat-classes:
#  ['asbytes', 'asstr', 'basestring', 'bytes', 'long', 'unicode']
#
# numpy.compat-functions:
#  ['asbytes_nested', 'asunicode', 'asunicode_nested', 'formatargspec', 'getargspec', 'getexception', 'isfileobj', 'npy_load_module', 'open_latin1', 'sixu']
#
# numpy.compat-modules:
#  ['_inspect', 'py3k']
#
# numpy.compat-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '__path__', 'absolute_import', 'division', 'integer_types', 'print_function', 'strchar']
#
# numpy.compat.py3k-builtins:
#  []
#
# numpy.compat.py3k-classes:
#  ['asbytes', 'asstr', 'basestring', 'bytes', 'long', 'unicode']
#
# numpy.compat.py3k-functions:
#  ['asbytes_nested', 'asunicode', 'asunicode_nested', 'getexception', 'isfileobj', 'npy_load_module', 'open_latin1', 'sixu']
#
# numpy.compat.py3k-modules:
#  ['sys']
#
# numpy.compat.py3k-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'integer_types', 'print_function', 'strchar']
#
# numpy.compat.py3k.sys:
#  This exists but I cannot inspect it
#
# numpy.core-builtins:
#  ['arange', 'array', 'busday_count', 'busday_offset', 'can_cast', 'compare_chararrays', 'concatenate', 'copyto', 'count_nonzero', 'datetime_as_string', 'datetime_data', 'dot', 'einsum', 'empty', 'empty_like', 'fastCopyAndTranspose', 'frombuffer', 'fromfile', 'fromiter', 'frompyfunc', 'fromstring', 'getbuffer', 'geterrobj', 'inner', 'int_asbuffer', 'is_busday', 'lexsort', 'loads', 'matmul', 'may_share_memory', 'min_scalar_type', 'nested_iters', 'newbuffer', 'promote_types', 'putmask', 'result_type', 'set_numeric_ops', 'seterrobj', 'shares_memory', 'vdot', 'where', 'zeros']
#
# numpy.core-classes:
#  ['ComplexWarning', 'MachAr', 'TooHardError', 'bool8', 'bool_', 'broadcast', 'busdaycalendar', 'byte', 'bytes_', 'cdouble', 'cfloat', 'character', 'chararray', 'clongdouble', 'clongfloat', 'complex128', 'complex256', 'complex64', 'complex_', 'complexfloating', 'csingle', 'datetime64', 'double', 'dtype', 'errstate', 'finfo', 'flatiter', 'flexible', 'float128', 'float16', 'float32', 'float64', 'float_', 'floating', 'format_parser', 'generic', 'half', 'iinfo', 'inexact', 'int0', 'int16', 'int32', 'int64', 'int8', 'int_', 'intc', 'integer', 'intp', 'longcomplex', 'longdouble', 'longfloat', 'longlong', 'memmap', 'ndarray', 'nditer', 'number', 'object0', 'object_', 'recarray', 'record', 'short', 'signedinteger', 'single', 'singlecomplex', 'str_', 'string0', 'string_', 'timedelta64', 'ubyte', 'ufunc', 'uint', 'uint0', 'uint16', 'uint32', 'uint64', 'uint8', 'uintc', 'uintp', 'ulonglong', 'unicode0', 'unicode_', 'unsignedinteger', 'ushort', 'void', 'void0']
#
# numpy.core-functions:
#  ['_numpy_tester', '_ufunc_reconstruct', 'alen', 'all', 'allclose', 'alltrue', 'alterdot', 'amax', 'amin', 'any', 'argmax', 'argmin', 'argpartition', 'argsort', 'argwhere', 'around', 'array2string', 'array_equal', 'array_equiv', 'array_repr', 'array_str', 'asanyarray', 'asarray', 'ascontiguousarray', 'asfortranarray', 'atleast_1d', 'atleast_2d', 'atleast_3d', 'base_repr', 'binary_repr', 'choose', 'clip', 'compress', 'convolve', 'correlate', 'cross', 'cumprod', 'cumproduct', 'cumsum', 'diagonal', 'find_common_type', 'flatnonzero', 'fromfunction', 'full', 'full_like', 'get_printoptions', 'getbufsize', 'geterr', 'geterrcall', 'hstack', 'identity', 'indices', 'isclose', 'isfortran', 'isscalar', 'issctype', 'issubdtype', 'linspace', 'load', 'logspace', 'max', 'maximum_sctype', 'mean', 'min', 'moveaxis', 'ndim', 'nonzero', 'obj2sctype', 'ones', 'ones_like', 'outer', 'partition', 'prod', 'product', 'ptp', 'put', 'rank', 'ravel', 'repeat', 'require', 'reshape', 'resize', 'restoredot', 'roll', 'rollaxis', 'round', 'round_', 'sctype2char', 'searchsorted', 'set_printoptions', 'set_string_function', 'setbufsize', 'seterr', 'seterrcall', 'shape', 'size', 'sometrue', 'sort', 'squeeze', 'stack', 'std', 'sum', 'swapaxes', 'take', 'tensordot', 'trace', 'transpose', 'var', 'vstack', 'zeros_like']
#
# numpy.core-modules:
#  ['_internal', '_methods', 'arrayprint', 'char', 'defchararray', 'fromnumeric', 'function_base', 'getlimits', 'info', 'machar', 'multiarray', 'numeric', 'numerictypes', 'rec', 'records', 'shape_base', 'umath']
#
# numpy.core-nofta:
#  ['ALLOW_THREADS', 'BUFSIZE', 'CLIP', 'ERR_CALL', 'ERR_DEFAULT', 'ERR_IGNORE', 'ERR_LOG', 'ERR_PRINT', 'ERR_RAISE', 'ERR_WARN', 'FLOATING_POINT_SUPPORT', 'FPE_DIVIDEBYZERO', 'FPE_INVALID', 'FPE_OVERFLOW', 'FPE_UNDERFLOW', 'False_', 'Inf', 'Infinity', 'MAXDIMS', 'MAY_SHARE_BOUNDS', 'MAY_SHARE_EXACT', 'NAN', 'NINF', 'NZERO', 'NaN', 'PINF', 'PZERO', 'RAISE', 'SHIFT_DIVIDEBYZERO', 'SHIFT_INVALID', 'SHIFT_OVERFLOW', 'SHIFT_UNDERFLOW', 'ScalarType', 'True_', 'UFUNC_BUFSIZE_DEFAULT', 'UFUNC_PYVALS_NAME', 'WRAP', '__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '__path__', '__version__', 'abs', 'absolute', 'absolute_import', 'add', 'arccos', 'arccosh', 'arcsin', 'arcsinh', 'arctan', 'arctan2', 'arctanh', 'bench', 'bitwise_and', 'bitwise_not', 'bitwise_or', 'bitwise_xor', 'cast', 'cbrt', 'ceil', 'conj', 'conjugate', 'copysign', 'cos', 'cosh', 'deg2rad', 'degrees', 'divide', 'division', 'e', 'equal', 'euler_gamma', 'exp', 'exp2', 'expm1', 'fabs', 'floor', 'floor_divide', 'fmax', 'fmin', 'fmod', 'frexp', 'greater', 'greater_equal', 'hypot', 'inf', 'infty', 'invert', 'isfinite', 'isinf', 'isnan', 'ldexp', 'left_shift', 'less', 'less_equal', 'little_endian', 'log', 'log10', 'log1p', 'log2', 'logaddexp', 'logaddexp2', 'logical_and', 'logical_not', 'logical_or', 'logical_xor', 'maximum', 'minimum', 'mod', 'modf', 'multiply', 'nan', 'nbytes', 'negative', 'newaxis', 'nextafter', 'not_equal', 'pi', 'power', 'print_function', 'rad2deg', 'radians', 'reciprocal', 'remainder', 'right_shift', 'rint', 'sctypeDict', 'sctypeNA', 'sctypes', 'sign', 'signbit', 'sin', 'sinh', 'spacing', 'sqrt', 'square', 'subtract', 'tan', 'tanh', 'test', 'true_divide', 'trunc', 'typeDict', 'typeNA', 'typecodes']
#
# numpy.core.arrayprint-builtins:
#  ['array', 'datetime_as_string', 'datetime_data', 'format_longfloat', 'reduce']
#
# numpy.core.arrayprint-classes:
#  ['ComplexFormat', 'DatetimeFormat', 'FloatFormat', 'IntegerFormat', 'LongComplexFormat', 'LongFloatFormat', 'TimedeltaFormat']
#
# numpy.core.arrayprint-functions:
#  ['_array2string', '_boolFormatter', '_convert_arrays', '_digits', '_extendLine', '_formatArray', '_leading_trailing', 'array2string', 'asarray', 'get_printoptions', 'product', 'ravel', 'repr_format', 'set_printoptions']
#
# numpy.core.arrayprint-modules:
#  ['_nt', 'sys']
#
# numpy.core.arrayprint-nofta:
#  ['_MAXINT', '_MININT', '__all__', '__builtins__', '__doc__', '__docformat__', '__file__', '__name__', '__package__', '_float_output_precision', '_float_output_suppress_small', '_formatter', '_inf_str', '_line_width', '_nan_str', '_summaryEdgeItems', '_summaryThreshold', 'absolute', 'absolute_import', 'division', 'isinf', 'isnan', 'maximum', 'minimum', 'not_equal', 'print_function']
#
# numpy.core.arrayprint.sys:
#  This exists but I cannot inspect it
#
# numpy.core.char:
#  This exists but I cannot inspect it
#
# numpy.core.defchararray-builtins:
#  ['_len', '_vec_string', 'compare_chararrays', 'narray']
#
# numpy.core.defchararray-classes:
#  ['_bytes', '_unicode', 'asbytes', 'bool_', 'character', 'chararray', 'integer', 'long', 'ndarray', 'object_', 'string_', 'unicode_']
#
# numpy.core.defchararray-functions:
#  ['_clean_args', '_get_num_chars', '_to_string_or_unicode_array', '_use_unicode', 'add', 'array', 'asarray', 'capitalize', 'center', 'count', 'decode', 'encode', 'endswith', 'equal', 'expandtabs', 'find', 'greater', 'greater_equal', 'index', 'isalnum', 'isalpha', 'isdecimal', 'isdigit', 'islower', 'isnumeric', 'isspace', 'istitle', 'isupper', 'join', 'less', 'less_equal', 'ljust', 'lower', 'lstrip', 'mod', 'multiply', 'not_equal', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'str_len', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
#
# numpy.core.defchararray-modules:
#  ['numpy', 'sys']
#
# numpy.core.defchararray-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '_globalvar', 'absolute_import', 'division', 'print_function']
#
# numpy.core.defchararray.numpy:
#  This exists but I cannot inspect it
#
# numpy.core.defchararray.sys:
#  This exists but I cannot inspect it
#
# numpy.core.fromnumeric-builtins:
#  ['_sum_', 'array', 'concatenate']
#
# numpy.core.fromnumeric-classes:
#  ['VisibleDeprecationWarning', '_gentype']
#
# numpy.core.fromnumeric-functions:
#  ['_dt_', '_wrapit', 'alen', 'all', 'alltrue', 'amax', 'amin', 'any', 'argmax', 'argmin', 'argpartition', 'argsort', 'around', 'asanyarray', 'asarray', 'choose', 'clip', 'compress', 'cumprod', 'cumproduct', 'cumsum', 'diagonal', 'mean', 'ndim', 'nonzero', 'partition', 'prod', 'product', 'ptp', 'put', 'rank', 'ravel', 'repeat', 'reshape', 'resize', 'round_', 'searchsorted', 'shape', 'size', 'sometrue', 'sort', 'squeeze', 'std', 'sum', 'swapaxes', 'take', 'trace', 'transpose', 'var']
#
# numpy.core.fromnumeric-modules:
#  ['_methods', 'mu', 'np', 'nt', 'types', 'um', 'warnings']
#
# numpy.core.fromnumeric-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'print_function']
#
# numpy.core.fromnumeric.mu:
#  This exists but I cannot inspect it
#
# numpy.core.fromnumeric.np:
#  This exists but I cannot inspect it
#
# numpy.core.fromnumeric.nt:
#  This exists but I cannot inspect it
#
# numpy.core.fromnumeric.types:
#  This exists but I cannot inspect it
#
# numpy.core.fromnumeric.um:
#  This exists but I cannot inspect it
#
# numpy.core.fromnumeric.warnings:
#  This exists but I cannot inspect it
#
# numpy.core.function_base-builtins:
#  ['result_type', 'shares_memory']
#
# numpy.core.function_base-classes:
#  ['TooHardError']
#
# numpy.core.function_base-functions:
#  ['linspace', 'logspace']
#
# numpy.core.function_base-modules:
#  ['_nx']
#
# numpy.core.function_base-nofta:
#  ['MAY_SHARE_BOUNDS', 'NaN', '__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'print_function']
#
# numpy.core.getlimits-builtins:
#  ['array']
#
# numpy.core.getlimits-classes:
#  ['MachAr', 'finfo', 'iinfo']
#
# numpy.core.getlimits-functions:
#  ['_frz']
#
# numpy.core.getlimits-modules:
#  ['ntypes', 'numeric']
#
# numpy.core.getlimits-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '_convert_to_float', 'absolute_import', 'division', 'print_function']
#
# numpy.core.getlimits.ntypes:
#  This exists but I cannot inspect it
#
# numpy.core.getlimits.numeric:
#  This exists but I cannot inspect it
#
# numpy.core.info-builtins:
#  []
#
# numpy.core.info-classes:
#  []
#
# numpy.core.info-functions:
#  []
#
# numpy.core.info-modules:
#  []
#
# numpy.core.info-nofta:
#  ['__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'depends', 'division', 'global_symbols', 'print_function']
#
# numpy.core.machar-builtins:
#  []
#
# numpy.core.machar-classes:
#  ['MachAr', 'errstate']
#
# numpy.core.machar-functions:
#  ['any']
#
# numpy.core.machar-modules:
#  []
#
# numpy.core.machar-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'print_function']
#
# numpy.core.multiarray-builtins:
#  ['_fastCopyAndTranspose', '_get_ndarray_c_version', '_insert', '_reconstruct', '_vec_string', 'add_docstring', 'arange', 'array', 'bincount', 'busday_count', 'busday_offset', 'can_cast', 'compare_chararrays', 'concatenate', 'copyto', 'correlate', 'correlate2', 'count_nonzero', 'datetime_as_string', 'datetime_data', 'digitize', 'dot', 'einsum', 'empty', 'empty_like', 'format_longfloat', 'frombuffer', 'fromfile', 'fromiter', 'fromstring', 'getbuffer', 'inner', 'int_asbuffer', 'interp', 'is_busday', 'lexsort', 'matmul', 'may_share_memory', 'min_scalar_type', 'nested_iters', 'newbuffer', 'packbits', 'promote_types', 'putmask', 'ravel_multi_index', 'result_type', 'scalar', 'set_datetimeparse_function', 'set_numeric_ops', 'set_string_function', 'set_typeDict', 'shares_memory', 'test_interrupt', 'unpackbits', 'unravel_index', 'vdot', 'where', 'zeros']
#
# numpy.core.multiarray-classes:
#  ['broadcast', 'busdaycalendar', 'dtype', 'error', 'flagsobj', 'flatiter', 'ndarray', 'nditer']
#
# numpy.core.multiarray-functions:
#  []
#
# numpy.core.multiarray-modules:
#  []
#
# numpy.core.multiarray-nofta:
#  ['ALLOW_THREADS', 'BUFSIZE', 'CLIP', 'DATETIMEUNITS', 'ITEM_HASOBJECT', 'ITEM_IS_POINTER', 'LIST_PICKLE', 'MAXDIMS', 'MAY_SHARE_BOUNDS', 'MAY_SHARE_EXACT', 'NEEDS_INIT', 'NEEDS_PYAPI', 'RAISE', 'USE_GETITEM', 'USE_SETITEM', 'WRAP', '_ARRAY_API', '__doc__', '__file__', '__name__', '__package__', '__version__', '_flagdict', 'typeinfo']
#
# numpy.core.numeric-builtins:
#  ['arange', 'array', 'busday_count', 'busday_offset', 'can_cast', 'compare_chararrays', 'concatenate', 'copyto', 'count_nonzero', 'datetime_as_string', 'datetime_data', 'dot', 'einsum', 'empty', 'empty_like', 'fastCopyAndTranspose', 'frombuffer', 'fromfile', 'fromiter', 'frompyfunc', 'fromstring', 'getbuffer', 'geterrobj', 'inner', 'int_asbuffer', 'is_busday', 'lexsort', 'loads', 'matmul', 'may_share_memory', 'min_scalar_type', 'nested_iters', 'newbuffer', 'promote_types', 'putmask', 'result_type', 'set_numeric_ops', 'seterrobj', 'shares_memory', 'vdot', 'where', 'zeros']
#
# numpy.core.numeric-classes:
#  ['ComplexWarning', 'TooHardError', '_unspecified', 'bool8', 'bool_', 'broadcast', 'busdaycalendar', 'byte', 'bytes_', 'cdouble', 'cfloat', 'character', 'clongdouble', 'clongfloat', 'complex128', 'complex256', 'complex64', 'complex_', 'complexfloating', 'csingle', 'datetime64', 'double', 'dtype', 'errstate', 'flatiter', 'flexible', 'float128', 'float16', 'float32', 'float64', 'float_', 'floating', 'generic', 'half', 'inexact', 'int0', 'int16', 'int32', 'int64', 'int8', 'int_', 'intc', 'integer', 'intp', 'longcomplex', 'longdouble', 'longfloat', 'longlong', 'ndarray', 'nditer', 'number', 'object0', 'object_', 'short', 'signedinteger', 'single', 'singlecomplex', 'str_', 'string0', 'string_', 'timedelta64', 'ubyte', 'ufunc', 'uint', 'uint0', 'uint16', 'uint32', 'uint64', 'uint8', 'uintc', 'uintp', 'ulonglong', 'unicode0', 'unicode_', 'unsignedinteger', 'ushort', 'void', 'void0']
#
# numpy.core.numeric-functions:
#  ['_maketup', '_mode_from_name', '_move_axis_to_0', '_setdef', '_validate_axis', 'alen', 'all', 'allclose', 'alltrue', 'alterdot', 'amax', 'amin', 'any', 'argmax', 'argmin', 'argpartition', 'argsort', 'argwhere', 'around', 'array2string', 'array_equal', 'array_equiv', 'array_repr', 'array_str', 'asanyarray', 'asarray', 'ascontiguousarray', 'asfortranarray', 'base_repr', 'binary_repr', 'choose', 'clip', 'compress', 'convolve', 'correlate', 'cross', 'cumprod', 'cumproduct', 'cumsum', 'diagonal', 'extend_all', 'find_common_type', 'flatnonzero', 'fromfunction', 'full', 'full_like', 'get_printoptions', 'getbufsize', 'geterr', 'geterrcall', 'identity', 'indices', 'isclose', 'isfortran', 'isscalar', 'issctype', 'issubdtype', 'load', 'maximum_sctype', 'mean', 'moveaxis', 'ndim', 'nonzero', 'obj2sctype', 'ones', 'ones_like', 'outer', 'partition', 'prod', 'product', 'ptp', 'put', 'rank', 'ravel', 'repeat', 'require', 'reshape', 'resize', 'restoredot', 'roll', 'rollaxis', 'round_', 'sctype2char', 'searchsorted', 'set_printoptions', 'set_string_function', 'setbufsize', 'seterr', 'seterrcall', 'shape', 'size', 'sometrue', 'sort', 'squeeze', 'std', 'sum', 'swapaxes', 'take', 'tensordot', 'trace', 'transpose', 'var', 'zeros_like']
#
# numpy.core.numeric-modules:
#  ['builtins', 'collections', 'fromnumeric', 'multiarray', 'numerictypes', 'operator', 'pickle', 'sys', 'umath', 'warnings']
#
# numpy.core.numeric-nofta:
#  ['ALLOW_THREADS', 'BUFSIZE', 'CLIP', 'ERR_CALL', 'ERR_DEFAULT', 'ERR_IGNORE', 'ERR_LOG', 'ERR_PRINT', 'ERR_RAISE', 'ERR_WARN', 'FLOATING_POINT_SUPPORT', 'FPE_DIVIDEBYZERO', 'FPE_INVALID', 'FPE_OVERFLOW', 'FPE_UNDERFLOW', 'False_', 'Inf', 'Infinity', 'MAXDIMS', 'MAY_SHARE_BOUNDS', 'MAY_SHARE_EXACT', 'NAN', 'NINF', 'NZERO', 'NaN', 'PINF', 'PZERO', 'RAISE', 'SHIFT_DIVIDEBYZERO', 'SHIFT_INVALID', 'SHIFT_OVERFLOW', 'SHIFT_UNDERFLOW', 'ScalarType', 'True_', 'UFUNC_BUFSIZE_DEFAULT', 'UFUNC_PYVALS_NAME', 'WRAP', '_Unspecified', '__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '_errdict', '_errdict_rev', '_lkup', '_mode_from_name_dict', '_typelessdata', 'absolute', 'absolute_import', 'add', 'arccos', 'arccosh', 'arcsin', 'arcsinh', 'arctan', 'arctan2', 'arctanh', 'bitwise_and', 'bitwise_not', 'bitwise_or', 'bitwise_xor', 'cast', 'cbrt', 'ceil', 'conj', 'conjugate', 'copysign', 'cos', 'cosh', 'deg2rad', 'degrees', 'divide', 'division', 'e', 'equal', 'euler_gamma', 'exp', 'exp2', 'expm1', 'fabs', 'floor', 'floor_divide', 'fmax', 'fmin', 'fmod', 'frexp', 'greater', 'greater_equal', 'hypot', 'inf', 'infty', 'invert', 'isfinite', 'isinf', 'isnan', 'ldexp', 'left_shift', 'less', 'less_equal', 'little_endian', 'log', 'log10', 'log1p', 'log2', 'logaddexp', 'logaddexp2', 'logical_and', 'logical_not', 'logical_or', 'logical_xor', 'maximum', 'minimum', 'mod', 'modf', 'multiply', 'nan', 'nbytes', 'negative', 'newaxis', 'nextafter', 'not_equal', 'pi', 'power', 'print_function', 'rad2deg', 'radians', 'reciprocal', 'remainder', 'right_shift', 'rint', 'sctypeDict', 'sctypeNA', 'sctypes', 'sign', 'signbit', 'sin', 'sinh', 'spacing', 'sqrt', 'square', 'subtract', 'tan', 'tanh', 'true_divide', 'trunc', 'typeDict', 'typeNA', 'typecodes']
#
# numpy.core.numeric.builtins:
#  This exists but I cannot inspect it
#
# numpy.core.numeric.collections:
#  This exists but I cannot inspect it
#
# numpy.core.numeric.fromnumeric:
#  This exists but I cannot inspect it
#
# numpy.core.numeric.multiarray:
#  This exists but I cannot inspect it
#
# numpy.core.numeric.numerictypes:
#  This exists but I cannot inspect it
#
# numpy.core.numeric.operator:
#  This exists but I cannot inspect it
#
# numpy.core.numeric.pickle:
#  This exists but I cannot inspect it
#
# numpy.core.numeric.sys:
#  This exists but I cannot inspect it
#
# numpy.core.numeric.umath:
#  This exists but I cannot inspect it
#
# numpy.core.numeric.warnings:
#  This exists but I cannot inspect it
#
# numpy.core.numerictypes-builtins:
#  ['array', 'busday_count', 'busday_offset', 'datetime_as_string', 'datetime_data', 'empty', 'is_busday']
#
# numpy.core.numerictypes-classes:
#  ['_typedict', 'bool', 'bool8', 'bool_', 'buffer_type', 'busdaycalendar', 'byte', 'bytes', 'bytes_', 'cdouble', 'cfloat', 'character', 'clongdouble', 'clongfloat', 'complex', 'complex128', 'complex256', 'complex64', 'complex_', 'complexfloating', 'csingle', 'datetime64', 'double', 'dtype', 'flexible', 'float', 'float128', 'float16', 'float32', 'float64', 'float_', 'floating', 'generic', 'half', 'inexact', 'int', 'int0', 'int16', 'int32', 'int64', 'int8', 'int_', 'intc', 'integer', 'intp', 'long', 'longcomplex', 'longdouble', 'longfloat', 'longlong', 'ndarray', 'number', 'object', 'object0', 'object_', 'short', 'signedinteger', 'single', 'singlecomplex', 'str', 'str_', 'string0', 'string_', 'timedelta64', 'ubyte', 'uint', 'uint0', 'uint16', 'uint32', 'uint64', 'uint8', 'uintc', 'uintp', 'ulonglong', 'unicode', 'unicode0', 'unicode_', 'unsignedinteger', 'ushort', 'void', 'void0']
#
# numpy.core.numerictypes-functions:
#  ['_add_aliases', '_add_array_type', '_add_integer_aliases', '_add_types', '_can_coerce_all', '_construct_char_code_lookup', '_construct_lookups', '_evalname', '_find_common_coerce', '_python_type', '_register_types', '_set_array_types', '_set_up_aliases', 'bitname', 'english_capitalize', 'english_lower', 'english_upper', 'find_common_type', 'issctype', 'issubclass_', 'issubdtype', 'issubsctype', 'maximum_sctype', 'obj2sctype', 'sctype2char']
#
# numpy.core.numerictypes-modules:
#  ['_types', 'numbers', 'sys']
#
# numpy.core.numerictypes-nofta:
#  ['LOWER_TABLE', 'ScalarType', 'UPPER_TABLE', '__all__', '__builtins__', '__doc__', '__file__', '__len_test_types', '__name__', '__package__', '__test_types', '_alignment', '_all_chars', '_ascii_lower', '_ascii_upper', '_kind_list', '_m', '_maxvals', '_minvals', '_python_types', '_sctype2char_dict', '_typestr', 'absolute_import', 'allTypes', 'cast', 'division', 'genericTypeRank', 'nbytes', 'print_function', 'sctypeDict', 'sctypeNA', 'sctypes', 'typeDict', 'typeNA', 'typecodes', 'typeinfo', 'val']
#
# numpy.core.numerictypes.numbers:
#  This exists but I cannot inspect it
#
# numpy.core.numerictypes.sys:
#  This exists but I cannot inspect it
#
# numpy.core.rec:
#  This exists but I cannot inspect it
#
# numpy.core.records-builtins:
#  []
#
# numpy.core.records-classes:
#  ['bytes', 'format_parser', 'long', 'ndarray', 'recarray', 'record']
#
# numpy.core.records-functions:
#  ['array', 'find_duplicate', 'fromarrays', 'fromfile', 'fromrecords', 'fromstring', 'get_remaining_size', 'isfileobj']
#
# numpy.core.records-modules:
#  ['nt', 'os', 'sb', 'sys']
#
# numpy.core.records-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '_byteorderconv', 'absolute_import', 'division', 'numfmt', 'print_function']
#
# numpy.core.records.nt:
#  This exists but I cannot inspect it
#
# numpy.core.records.os:
#  This exists but I cannot inspect it
#
# numpy.core.records.sb:
#  This exists but I cannot inspect it
#
# numpy.core.records.sys:
#  This exists but I cannot inspect it
#
# numpy.core.shape_base-builtins:
#  []
#
# numpy.core.shape_base-classes:
#  []
#
# numpy.core.shape_base-functions:
#  ['asanyarray', 'atleast_1d', 'atleast_2d', 'atleast_3d', 'hstack', 'stack', 'vstack']
#
# numpy.core.shape_base-modules:
#  ['_nx']
#
# numpy.core.shape_base-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'newaxis', 'print_function']
#
# numpy.core.umath-builtins:
#  ['_add_newdoc_ufunc', 'frompyfunc', 'geterrobj', 'seterrobj']
#
# numpy.core.umath-classes:
#  []
#
# numpy.core.umath-functions:
#  []
#
# numpy.core.umath-modules:
#  []
#
# numpy.core.umath-nofta:
#  ['ERR_CALL', 'ERR_DEFAULT', 'ERR_IGNORE', 'ERR_LOG', 'ERR_PRINT', 'ERR_RAISE', 'ERR_WARN', 'FLOATING_POINT_SUPPORT', 'FPE_DIVIDEBYZERO', 'FPE_INVALID', 'FPE_OVERFLOW', 'FPE_UNDERFLOW', 'NAN', 'NINF', 'NZERO', 'PINF', 'PZERO', 'SHIFT_DIVIDEBYZERO', 'SHIFT_INVALID', 'SHIFT_OVERFLOW', 'SHIFT_UNDERFLOW', 'UFUNC_BUFSIZE_DEFAULT', 'UFUNC_PYVALS_NAME', '_UFUNC_API', '__doc__', '__file__', '__name__', '__package__', '__version__', '_arg', '_ones_like', 'absolute', 'add', 'arccos', 'arccosh', 'arcsin', 'arcsinh', 'arctan', 'arctan2', 'arctanh', 'bitwise_and', 'bitwise_or', 'bitwise_xor', 'cbrt', 'ceil', 'conj', 'conjugate', 'copysign', 'cos', 'cosh', 'deg2rad', 'degrees', 'divide', 'e', 'equal', 'euler_gamma', 'exp', 'exp2', 'expm1', 'fabs', 'floor', 'floor_divide', 'fmax', 'fmin', 'fmod', 'frexp', 'greater', 'greater_equal', 'hypot', 'invert', 'isfinite', 'isinf', 'isnan', 'ldexp', 'left_shift', 'less', 'less_equal', 'log', 'log10', 'log1p', 'log2', 'logaddexp', 'logaddexp2', 'logical_and', 'logical_not', 'logical_or', 'logical_xor', 'maximum', 'minimum', 'mod', 'modf', 'multiply', 'negative', 'nextafter', 'not_equal', 'pi', 'power', 'rad2deg', 'radians', 'reciprocal', 'remainder', 'right_shift', 'rint', 'sign', 'signbit', 'sin', 'sinh', 'spacing', 'sqrt', 'square', 'subtract', 'tan', 'tanh', 'true_divide', 'trunc']
#
# numpy.ctypeslib-builtins:
#  ['array']
#
# numpy.ctypeslib-classes:
#  ['_ARRAY_TYPE', '_dtype', '_ndptr', '_ndptr_base', 'c_intp', 'flagsobj', 'integer', 'ndarray', 'tp']
#
# numpy.ctypeslib-functions:
#  ['_flags_fromnum', '_num_fromflags', 'as_array', 'as_ctypes', 'ctypes_load_library', 'deprecate', 'load_library', 'ndpointer', 'prep_array', 'prep_pointer', 'prep_simple']
#
# numpy.ctypeslib-modules:
#  ['ct', 'ctypes', 'os', 'sys']
#
# numpy.ctypeslib-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '_flagdict', '_flagnames', '_pointer_type_cache', '_typecodes', 'absolute_import', 'code', 'division', 'print_function', 'simple_types', 'types']
#
# numpy.ctypeslib.ct:
#  This exists but I cannot inspect it
#
# numpy.ctypeslib.ctypes:
#  This exists but I cannot inspect it
#
# numpy.ctypeslib.os:
#  This exists but I cannot inspect it
#
# numpy.ctypeslib.sys:
#  This exists but I cannot inspect it
#
# numpy.emath:
#  This exists but I cannot inspect it
#
# numpy.fft-builtins:
#  []
#
# numpy.fft-classes:
#  []
#
# numpy.fft-functions:
#  ['_numpy_tester', 'fft', 'fft2', 'fftfreq', 'fftn', 'fftshift', 'hfft', 'ifft', 'ifft2', 'ifftn', 'ifftshift', 'ihfft', 'irfft', 'irfft2', 'irfftn', 'rfft', 'rfft2', 'rfftfreq', 'rfftn']
#
# numpy.fft-modules:
#  ['fftpack', 'fftpack_lite', 'helper', 'info']
#
# numpy.fft-nofta:
#  ['__builtins__', '__doc__', '__file__', '__name__', '__package__', '__path__', 'absolute_import', 'bench', 'division', 'print_function', 'test', 'using_mklfft']
#
# numpy.fft.fftpack-builtins:
#  ['array', 'zeros']
#
# numpy.fft.fftpack-classes:
#  []
#
# numpy.fft.fftpack-functions:
#  ['_cook_nd_args', '_raw_fft', '_raw_fftnd', '_unitary', 'asarray', 'fft', 'fft2', 'fftn', 'hfft', 'ifft', 'ifft2', 'ifftn', 'ihfft', 'irfft', 'irfft2', 'irfftn', 'rfft', 'rfft2', 'rfftn', 'shape', 'swapaxes', 'take']
#
# numpy.fft.fftpack-modules:
#  ['fftpack']
#
# numpy.fft.fftpack-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '_fft_cache', '_real_fft_cache', 'absolute_import', 'conjugate', 'division', 'print_function', 'sqrt']
#
# numpy.fft.fftpack.fftpack:
#  This exists but I cannot inspect it
#
# numpy.fft.fftpack_lite-builtins:
#  ['cfftb', 'cfftf', 'cffti', 'rfftb', 'rfftf', 'rffti']
#
# numpy.fft.fftpack_lite-classes:
#  ['error']
#
# numpy.fft.fftpack_lite-functions:
#  []
#
# numpy.fft.fftpack_lite-modules:
#  []
#
# numpy.fft.fftpack_lite-nofta:
#  ['__doc__', '__file__', '__name__', '__package__']
#
# numpy.fft.helper-builtins:
#  ['arange', 'concatenate', 'empty']
#
# numpy.fft.helper-classes:
#  ['integer']
#
# numpy.fft.helper-functions:
#  ['asarray', 'fftfreq', 'fftshift', 'ifftshift', 'rfftfreq', 'take']
#
# numpy.fft.helper-modules:
#  []
#
# numpy.fft.helper-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'integer_types', 'print_function']
#
# numpy.fft.info-builtins:
#  []
#
# numpy.fft.info-classes:
#  []
#
# numpy.fft.info-functions:
#  []
#
# numpy.fft.info-modules:
#  []
#
# numpy.fft.info-nofta:
#  ['__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'depends', 'division', 'print_function']
#
# numpy.lib-builtins:
#  ['add_docstring', 'add_newdoc_ufunc', 'bincount', 'digitize', 'loads', 'packbits', 'ravel_multi_index', 'unpackbits', 'unravel_index']
#
# numpy.lib-classes:
#  ['Arrayterator', 'DataSource', 'NumpyVersion', 'RankWarning', 'ndenumerate', 'ndindex', 'poly1d', 'vectorize']
#
# numpy.lib-functions:
#  ['_numpy_tester', 'add_newdoc', 'angle', 'append', 'apply_along_axis', 'apply_over_axes', 'array_split', 'asarray_chkfinite', 'asfarray', 'asscalar', 'average', 'bartlett', 'blackman', 'broadcast_arrays', 'broadcast_to', 'byte_bounds', 'column_stack', 'common_type', 'copy', 'corrcoef', 'cov', 'delete', 'deprecate', 'deprecate_with_doc', 'diag', 'diag_indices', 'diag_indices_from', 'diagflat', 'diff', 'disp', 'dsplit', 'dstack', 'ediff1d', 'expand_dims', 'extract', 'eye', 'fill_diagonal', 'fix', 'fliplr', 'flipud', 'fromregex', 'fv', 'genfromtxt', 'get_array_wrap', 'get_include', 'gradient', 'hamming', 'hanning', 'histogram', 'histogram2d', 'histogramdd', 'hsplit', 'i0', 'imag', 'in1d', 'info', 'insert', 'interp', 'intersect1d', 'ipmt', 'irr', 'iscomplex', 'iscomplexobj', 'isneginf', 'isposinf', 'isreal', 'isrealobj', 'issubclass_', 'issubdtype', 'issubsctype', 'iterable', 'ix_', 'kaiser', 'kron', 'load', 'loadtxt', 'lookfor', 'mafromtxt', 'mask_indices', 'median', 'meshgrid', 'mintypecode', 'mirr', 'msort', 'nan_to_num', 'nanargmax', 'nanargmin', 'nanmax', 'nanmean', 'nanmedian', 'nanmin', 'nanpercentile', 'nanprod', 'nanstd', 'nansum', 'nanvar', 'ndfromtxt', 'nper', 'npv', 'pad', 'percentile', 'piecewise', 'place', 'pmt', 'poly', 'polyadd', 'polyder', 'polydiv', 'polyfit', 'polyint', 'polymul', 'polysub', 'polyval', 'ppmt', 'pv', 'rate', 'real', 'real_if_close', 'recfromcsv', 'recfromtxt', 'roots', 'rot90', 'row_stack', 'safe_eval', 'save', 'savetxt', 'savez', 'savez_compressed', 'select', 'setdiff1d', 'setxor1d', 'sinc', 'sort_complex', 'source', 'split', 'tile', 'trapz', 'tri', 'tril', 'tril_indices', 'tril_indices_from', 'trim_zeros', 'triu', 'triu_indices', 'triu_indices_from', 'typename', 'union1d', 'unique', 'unwrap', 'vander', 'vsplit', 'who']
#
# numpy.lib-modules:
#  ['_datasource', '_iotools', '_version', 'arraypad', 'arraysetops', 'arrayterator', 'emath', 'financial', 'format', 'function_base', 'index_tricks', 'math', 'nanfunctions', 'npyio', 'polynomial', 'scimath', 'shape_base', 'stride_tricks', 'twodim_base', 'type_check', 'ufunclike', 'utils']
#
# numpy.lib-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '__path__', '__version__', 'absolute_import', 'bench', 'c_', 'division', 'index_exp', 'mgrid', 'ogrid', 'print_function', 'r_', 's_', 'test']
#
# numpy.lib.arraypad-builtins:
#  []
#
# numpy.lib.arraypad-classes:
#  []
#
# numpy.lib.arraypad-functions:
#  ['_append_const', '_append_edge', '_append_max', '_append_mean', '_append_med', '_append_min', '_append_ramp', '_arange_ndarray', '_normalize_shape', '_pad_ref', '_pad_sym', '_pad_wrap', '_prepend_const', '_prepend_edge', '_prepend_max', '_prepend_mean', '_prepend_med', '_prepend_min', '_prepend_ramp', '_round_ifneeded', '_validate_lengths', 'pad']
#
# numpy.lib.arraypad-modules:
#  ['np']
#
# numpy.lib.arraypad-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'print_function']
#
# numpy.lib.arraypad.np:
#  This exists but I cannot inspect it
#
# numpy.lib.arraysetops-builtins:
#  []
#
# numpy.lib.arraysetops-classes:
#  []
#
# numpy.lib.arraysetops-functions:
#  ['ediff1d', 'in1d', 'intersect1d', 'setdiff1d', 'setxor1d', 'union1d', 'unique']
#
# numpy.lib.arraysetops-modules:
#  ['np']
#
# numpy.lib.arraysetops-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'print_function']
#
# numpy.lib.arraysetops.np:
#  This exists but I cannot inspect it
#
# numpy.lib.arrayterator-builtins:
#  ['mul', 'reduce']
#
# numpy.lib.arrayterator-classes:
#  ['Arrayterator', 'long']
#
# numpy.lib.arrayterator-functions:
#  []
#
# numpy.lib.arrayterator-modules:
#  []
#
# numpy.lib.arrayterator-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'print_function']
#
# numpy.lib.emath:
#  This exists but I cannot inspect it
#
# numpy.lib.financial-builtins:
#  []
#
# numpy.lib.financial-classes:
#  []
#
# numpy.lib.financial-functions:
#  ['_convert_when', '_g_div_gp', '_rbl', 'fv', 'ipmt', 'irr', 'mirr', 'nper', 'npv', 'pmt', 'ppmt', 'pv', 'rate']
#
# numpy.lib.financial-modules:
#  ['np']
#
# numpy.lib.financial-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '_when_to_num', 'absolute_import', 'division', 'print_function']
#
# numpy.lib.financial.np:
#  This exists but I cannot inspect it
#
# numpy.lib.format-builtins:
#  []
#
# numpy.lib.format-classes:
#  ['asbytes', 'asstr', 'basestring', 'long']
#
# numpy.lib.format-functions:
#  ['_check_version', '_filter_header', '_read_array_header', '_read_bytes', '_write_array_header', 'dtype_to_descr', 'header_data_from_array_1_0', 'isfileobj', 'magic', 'open_memmap', 'read_array', 'read_array_header_1_0', 'read_array_header_2_0', 'read_magic', 'safe_eval', 'write_array', 'write_array_header_1_0', 'write_array_header_2_0']
#
# numpy.lib.format-modules:
#  ['io', 'numpy', 'pickle', 'sys', 'warnings']
#
# numpy.lib.format-nofta:
#  ['BUFFER_SIZE', 'MAGIC_LEN', 'MAGIC_PREFIX', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'print_function']
#
# numpy.lib.format.io:
#  This exists but I cannot inspect it
#
# numpy.lib.format.numpy:
#  This exists but I cannot inspect it
#
# numpy.lib.format.pickle:
#  This exists but I cannot inspect it
#
# numpy.lib.format.sys:
#  This exists but I cannot inspect it
#
# numpy.lib.format.warnings:
#  This exists but I cannot inspect it
#
# numpy.lib.function_base-builtins:
#  ['_insert', 'add_docstring', 'add_newdoc_ufunc', 'arange', 'array', 'bincount', 'compiled_interp', 'concatenate', 'digitize', 'dot', 'empty', 'empty_like', 'frompyfunc', 'where', 'zeros']
#
# numpy.lib.function_base-classes:
#  ['basestring', 'integer', 'intp', 'long', 'ndarray', 'number', 'range', 'vectorize']
#
# numpy.lib.function_base-functions:
#  ['_chbevl', '_hist_bin_auto', '_hist_bin_doane', '_hist_bin_fd', '_hist_bin_rice', '_hist_bin_scott', '_hist_bin_sqrt', '_hist_bin_sturges', '_i0_1', '_i0_2', '_median', '_percentile', '_ureduce', 'add_newdoc', 'angle', 'any', 'append', 'around', 'asanyarray', 'asarray', 'asarray_chkfinite', 'atleast_1d', 'atleast_2d', 'average', 'bartlett', 'blackman', 'copy', 'corrcoef', 'cov', 'delete', 'deprecate', 'diag', 'diff', 'disp', 'extract', 'gradient', 'hamming', 'hanning', 'histogram', 'histogramdd', 'i0', 'insert', 'interp', 'isscalar', 'iterable', 'kaiser', 'linspace', 'mean', 'median', 'meshgrid', 'msort', 'nonzero', 'ones', 'partition', 'percentile', 'piecewise', 'place', 'ravel', 'select', 'sinc', 'sort', 'sort_complex', 'sum', 'take', 'trapz', 'trim_zeros', 'unique', 'unwrap']
#
# numpy.lib.function_base-modules:
#  ['_nx', 'collections', 'np', 'operator', 'sys', 'warnings']
#
# numpy.lib.function_base-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '_hist_bin_selectors', '_i0A', '_i0B', 'absolute_import', 'add', 'arctan2', 'ceil', 'cos', 'division', 'exp', 'floor', 'less_equal', 'log10', 'mod', 'multiply', 'pi', 'print_function', 'sin', 'sqrt', 'typecodes']
#
# numpy.lib.function_base.collections:
#  This exists but I cannot inspect it
#
# numpy.lib.function_base.np:
#  This exists but I cannot inspect it
#
# numpy.lib.function_base.operator:
#  This exists but I cannot inspect it
#
# numpy.lib.function_base.sys:
#  This exists but I cannot inspect it
#
# numpy.lib.function_base.warnings:
#  This exists but I cannot inspect it
#
# numpy.lib.index_tricks-builtins:
#  ['arange', 'array', 'ravel_multi_index', 'unravel_index']
#
# numpy.lib.index_tricks-classes:
#  ['AxisConcatenator', 'CClass', 'IndexExpression', 'RClass', 'makemat', 'nd_grid', 'ndenumerate', 'ndindex']
#
# numpy.lib.index_tricks-functions:
#  ['alltrue', 'as_strided', 'asarray', 'cumprod', 'diag_indices', 'diag_indices_from', 'diff', 'fill_diagonal', 'find_common_type', 'issubdtype', 'ix_']
#
# numpy.lib.index_tricks-modules:
#  ['_nx', 'function_base', 'math', 'matrix', 'sys']
#
# numpy.lib.index_tricks-nofta:
#  ['ScalarType', '__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'c_', 'division', 'index_exp', 'mgrid', 'ogrid', 'print_function', 'r_', 's_']
#
# numpy.lib.index_tricks.function_base:
#  This exists but I cannot inspect it
#
# numpy.lib.index_tricks.math:
#  This exists but I cannot inspect it
#
# numpy.lib.index_tricks.matrix:
#  This exists but I cannot inspect it
#
# numpy.lib.index_tricks.sys:
#  This exists but I cannot inspect it
#
# numpy.lib.math:
#  This exists but I cannot inspect it
#
# numpy.lib.nanfunctions-builtins:
#  []
#
# numpy.lib.nanfunctions-classes:
#  []
#
# numpy.lib.nanfunctions-functions:
#  ['_copyto', '_divide_by_count', '_nanmedian', '_nanmedian1d', '_nanmedian_small', '_nanpercentile', '_nanpercentile1d', '_replace_nan', '_ureduce', 'nanargmax', 'nanargmin', 'nanmax', 'nanmean', 'nanmedian', 'nanmin', 'nanpercentile', 'nanprod', 'nanstd', 'nansum', 'nanvar']
#
# numpy.lib.nanfunctions-modules:
#  ['np', 'warnings']
#
# numpy.lib.nanfunctions-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'print_function']
#
# numpy.lib.nanfunctions.np:
#  This exists but I cannot inspect it
#
# numpy.lib.nanfunctions.warnings:
#  This exists but I cannot inspect it
#
# numpy.lib.npyio-builtins:
#  ['loads', 'packbits', 'unpackbits']
#
# numpy.lib.npyio-classes:
#  ['BagObj', 'ConversionWarning', 'ConverterError', 'ConverterLockError', 'DataSource', 'LineSplitter', 'NameValidator', 'NpzFile', 'StringConverter', '_bytes_to_name', 'asbytes', 'asstr', 'basestring', 'bytes', 'itemgetter', 'map', 'unicode']
#
# numpy.lib.npyio-functions:
#  ['_getconv', '_is_string_like', '_savez', 'asbytes_nested', 'easy_dtype', 'flatten_dtype', 'fromregex', 'genfromtxt', 'has_nested_fields', 'load', 'loadtxt', 'mafromtxt', 'ndfromtxt', 'recfromcsv', 'recfromtxt', 'save', 'savetxt', 'savez', 'savez_compressed', 'zipfile_factory']
#
# numpy.lib.npyio-modules:
#  ['format', 'itertools', 'np', 'os', 'pickle', 're', 'sys', 'warnings', 'weakref']
#
# numpy.lib.npyio-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'print_function']
#
# numpy.lib.npyio.format:
#  This exists but I cannot inspect it
#
# numpy.lib.npyio.itertools:
#  This exists but I cannot inspect it
#
# numpy.lib.npyio.np:
#  This exists but I cannot inspect it
#
# numpy.lib.npyio.os:
#  This exists but I cannot inspect it
#
# numpy.lib.npyio.pickle:
#  This exists but I cannot inspect it
#
# numpy.lib.npyio.re:
#  This exists but I cannot inspect it
#
# numpy.lib.npyio.sys:
#  This exists but I cannot inspect it
#
# numpy.lib.npyio.warnings:
#  This exists but I cannot inspect it
#
# numpy.lib.npyio.weakref:
#  This exists but I cannot inspect it
#
# numpy.lib.polynomial-builtins:
#  ['array', 'dot']
#
# numpy.lib.polynomial-classes:
#  ['RankWarning', 'finfo', 'poly1d']
#
# numpy.lib.polynomial-functions:
#  ['_raise_power', 'atleast_1d', 'diag', 'eigvals', 'hstack', 'imag', 'inv', 'iscomplex', 'isscalar', 'lstsq', 'mintypecode', 'ones', 'poly', 'polyadd', 'polyder', 'polydiv', 'polyfit', 'polyint', 'polymul', 'polysub', 'polyval', 'real', 'roots', 'sort_complex', 'trim_zeros', 'vander']
#
# numpy.lib.polynomial-modules:
#  ['NX', 're', 'warnings']
#
# numpy.lib.polynomial-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '_poly_mat', 'abs', 'absolute_import', 'division', 'print_function']
#
# numpy.lib.polynomial.NX:
#  This exists but I cannot inspect it
#
# numpy.lib.polynomial.re:
#  This exists but I cannot inspect it
#
# numpy.lib.polynomial.warnings:
#  This exists but I cannot inspect it
#
# numpy.lib.scimath-builtins:
#  []
#
# numpy.lib.scimath-classes:
#  []
#
# numpy.lib.scimath-functions:
#  ['_fix_int_lt_zero', '_fix_real_abs_gt_1', '_fix_real_lt_zero', '_tocomplex', 'any', 'arccos', 'arcsin', 'arctanh', 'asarray', 'isreal', 'log', 'log10', 'log2', 'logn', 'power', 'sqrt']
#
# numpy.lib.scimath-modules:
#  ['nt', 'nx']
#
# numpy.lib.scimath-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '_ln2', 'absolute_import', 'division', 'print_function']
#
# numpy.lib.scimath.nt:
#  This exists but I cannot inspect it
#
# numpy.lib.scimath.nx:
#  This exists but I cannot inspect it
#
# numpy.lib.shape_base-builtins:
#  ['array', 'concatenate', 'zeros']
#
# numpy.lib.shape_base-classes:
#  []
#
# numpy.lib.shape_base-functions:
#  ['_replace_zero_by_x_arrays', 'apply_along_axis', 'apply_over_axes', 'array_split', 'asanyarray', 'asarray', 'atleast_3d', 'column_stack', 'dsplit', 'dstack', 'expand_dims', 'get_array_prepare', 'get_array_wrap', 'hsplit', 'isscalar', 'kron', 'outer', 'product', 'reshape', 'row_stack', 'split', 'tile', 'vsplit', 'vstack']
#
# numpy.lib.shape_base-modules:
#  ['_nx', 'warnings']
#
# numpy.lib.shape_base-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'print_function']
#
# numpy.lib.shape_base.warnings:
#  This exists but I cannot inspect it
#
# numpy.lib.stride_tricks-builtins:
#  []
#
# numpy.lib.stride_tricks-classes:
#  ['DummyArray']
#
# numpy.lib.stride_tricks-functions:
#  ['_broadcast_shape', '_broadcast_to', '_maybe_view_as_subclass', 'as_strided', 'broadcast_arrays', 'broadcast_to']
#
# numpy.lib.stride_tricks-modules:
#  ['np']
#
# numpy.lib.stride_tricks-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'print_function']
#
# numpy.lib.stride_tricks.np:
#  This exists but I cannot inspect it
#
# numpy.lib.twodim_base-builtins:
#  ['arange', 'empty', 'promote_types', 'where', 'zeros']
#
# numpy.lib.twodim_base-classes:
#  ['iinfo', 'int16', 'int32', 'int64', 'int8']
#
# numpy.lib.twodim_base-functions:
# ...
#
# numpy.ma.extras.umath:
#  This exists but I cannot inspect it
#
# numpy.ma.extras.warnings:
#  This exists but I cannot inspect it
#
# numpy.math:
#  This exists but I cannot inspect it
#
# numpy.matrixlib-builtins:
#  []
#
# numpy.matrixlib-classes:
#  ['matrix']
#
# numpy.matrixlib-functions:
#  ['_numpy_tester', 'asmatrix', 'bmat', 'mat']
#
# numpy.matrixlib-modules:
#  ['defmatrix']
#
# numpy.matrixlib-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '__path__', 'absolute_import', 'bench', 'division', 'print_function', 'test']
#
# numpy.matrixlib.defmatrix-builtins:
#  ['concatenate']
#
# numpy.matrixlib.defmatrix-classes:
#  ['matrix']
#
# numpy.matrixlib.defmatrix-functions:
#  ['_convert_from_string', '_eval', '_from_string', 'asanyarray', 'asmatrix', 'binary_repr', 'bmat', 'identity', 'isscalar', 'issubdtype', 'mat', 'matrix_power']
#
# numpy.matrixlib.defmatrix-modules:
#  ['N', 'sys']
#
# numpy.matrixlib.defmatrix-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '_numchars', '_table', '_todelete', 'absolute_import', 'division', 'print_function']
#
# numpy.matrixlib.defmatrix.N:
#  This exists but I cannot inspect it
#
# numpy.matrixlib.defmatrix.sys:
#  This exists but I cannot inspect it
#
# numpy.polynomial-builtins:
#  []
#
# numpy.polynomial-classes:
#  ['Chebyshev', 'Hermite', 'HermiteE', 'Laguerre', 'Legendre', 'Polynomial']
#
# numpy.polynomial-functions:
#  ['_numpy_tester']
#
# numpy.polynomial-modules:
#  ['_polybase', 'chebyshev', 'hermite', 'hermite_e', 'laguerre', 'legendre', 'polynomial', 'polyutils']
#
# numpy.polynomial-nofta:
#  ['__builtins__', '__doc__', '__file__', '__name__', '__package__', '__path__', 'absolute_import', 'bench', 'division', 'print_function', 'test']
#
# numpy.polynomial.chebyshev-builtins:
#  []
#
# numpy.polynomial.chebyshev-classes:
#  ['ABCPolyBase', 'Chebyshev']
#
# numpy.polynomial.chebyshev-functions:
#  ['_cseries_to_zseries', '_zseries_der', '_zseries_div', '_zseries_int', '_zseries_mul', '_zseries_to_cseries', 'cheb2poly', 'chebadd', 'chebcompanion', 'chebder', 'chebdiv', 'chebfit', 'chebfromroots', 'chebgauss', 'chebgrid2d', 'chebgrid3d', 'chebint', 'chebline', 'chebmul', 'chebmulx', 'chebpow', 'chebpts1', 'chebpts2', 'chebroots', 'chebsub', 'chebtrim', 'chebval', 'chebval2d', 'chebval3d', 'chebvander', 'chebvander2d', 'chebvander3d', 'chebweight', 'poly2cheb']
#
# numpy.polynomial.chebyshev-modules:
#  ['la', 'np', 'pu', 'warnings']
#
# numpy.polynomial.chebyshev-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'chebdomain', 'chebone', 'chebx', 'chebzero', 'division', 'print_function']
#
# numpy.polynomial.chebyshev.la:
#  This exists but I cannot inspect it
#
# numpy.polynomial.chebyshev.np:
#  This exists but I cannot inspect it
#
# numpy.polynomial.chebyshev.pu:
#  This exists but I cannot inspect it
#
# numpy.polynomial.chebyshev.warnings:
#  This exists but I cannot inspect it
#
# numpy.polynomial.hermite-builtins:
#  []
#
# numpy.polynomial.hermite-classes:
#  ['ABCPolyBase', 'Hermite']
#
# numpy.polynomial.hermite-functions:
#  ['_normed_hermite_n', 'herm2poly', 'hermadd', 'hermcompanion', 'hermder', 'hermdiv', 'hermfit', 'hermfromroots', 'hermgauss', 'hermgrid2d', 'hermgrid3d', 'hermint', 'hermline', 'hermmul', 'hermmulx', 'hermpow', 'hermroots', 'hermsub', 'hermtrim', 'hermval', 'hermval2d', 'hermval3d', 'hermvander', 'hermvander2d', 'hermvander3d', 'hermweight', 'poly2herm']
#
# numpy.polynomial.hermite-modules:
#  ['la', 'np', 'pu', 'warnings']
#
# numpy.polynomial.hermite-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'hermdomain', 'hermone', 'hermx', 'hermzero', 'print_function']
#
# numpy.polynomial.hermite.la:
#  This exists but I cannot inspect it
#
# numpy.polynomial.hermite.np:
#  This exists but I cannot inspect it
#
# numpy.polynomial.hermite.pu:
#  This exists but I cannot inspect it
#
# numpy.polynomial.hermite.warnings:
#  This exists but I cannot inspect it
#
# numpy.polynomial.hermite_e-builtins:
#  []
#
# numpy.polynomial.hermite_e-classes:
#  ['ABCPolyBase', 'HermiteE']
#
# numpy.polynomial.hermite_e-functions:
#  ['_normed_hermite_e_n', 'herme2poly', 'hermeadd', 'hermecompanion', 'hermeder', 'hermediv', 'hermefit', 'hermefromroots', 'hermegauss', 'hermegrid2d', 'hermegrid3d', 'hermeint', 'hermeline', 'hermemul', 'hermemulx', 'hermepow', 'hermeroots', 'hermesub', 'hermetrim', 'hermeval', 'hermeval2d', 'hermeval3d', 'hermevander', 'hermevander2d', 'hermevander3d', 'hermeweight', 'poly2herme']
#
# numpy.polynomial.hermite_e-modules:
#  ['la', 'np', 'pu', 'warnings']
#
# numpy.polynomial.hermite_e-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'hermedomain', 'hermeone', 'hermex', 'hermezero', 'print_function']
#
# numpy.polynomial.hermite_e.la:
#  This exists but I cannot inspect it
#
# numpy.polynomial.hermite_e.np:
#  This exists but I cannot inspect it
#
# numpy.polynomial.hermite_e.pu:
#  This exists but I cannot inspect it
#
# numpy.polynomial.hermite_e.warnings:
#  This exists but I cannot inspect it
#
# numpy.polynomial.laguerre-builtins:
#  []
#
# numpy.polynomial.laguerre-classes:
#  ['ABCPolyBase', 'Laguerre']
#
# numpy.polynomial.laguerre-functions:
#  ['lag2poly', 'lagadd', 'lagcompanion', 'lagder', 'lagdiv', 'lagfit', 'lagfromroots', 'laggauss', 'laggrid2d', 'laggrid3d', 'lagint', 'lagline', 'lagmul', 'lagmulx', 'lagpow', 'lagroots', 'lagsub', 'lagtrim', 'lagval', 'lagval2d', 'lagval3d', 'lagvander', 'lagvander2d', 'lagvander3d', 'lagweight', 'poly2lag']
#
# numpy.polynomial.laguerre-modules:
#  ['la', 'np', 'pu', 'warnings']
#
# numpy.polynomial.laguerre-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'lagdomain', 'lagone', 'lagx', 'lagzero', 'print_function']
#
# numpy.polynomial.laguerre.la:
#  This exists but I cannot inspect it
#
# numpy.polynomial.laguerre.np:
#  This exists but I cannot inspect it
#
# numpy.polynomial.laguerre.pu:
#  This exists but I cannot inspect it
#
# numpy.polynomial.laguerre.warnings:
#  This exists but I cannot inspect it
#
# numpy.polynomial.legendre-builtins:
#  []
#
# numpy.polynomial.legendre-classes:
#  ['ABCPolyBase', 'Legendre']
#
# numpy.polynomial.legendre-functions:
#  ['leg2poly', 'legadd', 'legcompanion', 'legder', 'legdiv', 'legfit', 'legfromroots', 'leggauss', 'leggrid2d', 'leggrid3d', 'legint', 'legline', 'legmul', 'legmulx', 'legpow', 'legroots', 'legsub', 'legtrim', 'legval', 'legval2d', 'legval3d', 'legvander', 'legvander2d', 'legvander3d', 'legweight', 'poly2leg']
#
# numpy.polynomial.legendre-modules:
#  ['la', 'np', 'pu', 'warnings']
#
# numpy.polynomial.legendre-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'legdomain', 'legone', 'legx', 'legzero', 'print_function']
#
# numpy.polynomial.legendre.la:
#  This exists but I cannot inspect it
#
# numpy.polynomial.legendre.np:
#  This exists but I cannot inspect it
#
# numpy.polynomial.legendre.pu:
#  This exists but I cannot inspect it
#
# numpy.polynomial.legendre.warnings:
#  This exists but I cannot inspect it
#
# numpy.polynomial.polynomial-builtins:
#  []
#
# numpy.polynomial.polynomial-classes:
#  ['ABCPolyBase', 'Polynomial']
#
# numpy.polynomial.polynomial-functions:
#  ['polyadd', 'polycompanion', 'polyder', 'polydiv', 'polyfit', 'polyfromroots', 'polygrid2d', 'polygrid3d', 'polyint', 'polyline', 'polymul', 'polymulx', 'polypow', 'polyroots', 'polysub', 'polytrim', 'polyval', 'polyval2d', 'polyval3d', 'polyvander', 'polyvander2d', 'polyvander3d']
#
# numpy.polynomial.polynomial-modules:
#  ['la', 'np', 'pu', 'warnings']
#
# numpy.polynomial.polynomial-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'polydomain', 'polyone', 'polyx', 'polyzero', 'print_function']
#
# numpy.polynomial.polynomial.la:
#  This exists but I cannot inspect it
#
# numpy.polynomial.polynomial.np:
#  This exists but I cannot inspect it
#
# numpy.polynomial.polynomial.pu:
#  This exists but I cannot inspect it
#
# numpy.polynomial.polynomial.warnings:
#  This exists but I cannot inspect it
#
# numpy.polynomial.polyutils-builtins:
#  []
#
# numpy.polynomial.polyutils-classes:
#  ['PolyBase', 'PolyDomainError', 'PolyError', 'RankWarning']
#
# numpy.polynomial.polyutils-functions:
#  ['as_series', 'getdomain', 'mapdomain', 'mapparms', 'trimcoef', 'trimseq']
#
# numpy.polynomial.polyutils-modules:
#  ['np']
#
# numpy.polynomial.polyutils-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'print_function']
#
# numpy.polynomial.polyutils.np:
#  This exists but I cannot inspect it
#
# numpy.random-builtins:
#  ['Lock', 'beta', 'binomial', 'bytes', 'chisquare', 'choice', 'dirichlet', 'exponential', 'f', 'gamma', 'geometric', 'get_state', 'gumbel', 'hypergeometric', 'laplace', 'logistic', 'lognormal', 'logseries', 'multinomial', 'multivariate_normal', 'negative_binomial', 'noncentral_chisquare', 'noncentral_f', 'normal', 'pareto', 'permutation', 'poisson', 'power', 'rand', 'randint', 'randn', 'random', 'random_integers', 'random_sample', 'ranf', 'rayleigh', 'sample', 'seed', 'set_state', 'shuffle', 'standard_cauchy', 'standard_exponential', 'standard_gamma', 'standard_normal', 'standard_t', 'triangular', 'uniform', 'vonmises', 'wald', 'weibull', 'zipf']
#
# numpy.random-classes:
#  ['RandomState']
#
# numpy.random-functions:
#  ['__RandomState_ctor', '_numpy_tester']
#
# numpy.random-modules:
#  ['info', 'mtrand', 'np', 'operator', 'warnings']
#
# numpy.random-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '__path__', '__warningregistry__', 'absolute_import', 'bench', 'division', 'print_function', 'test']
#
# numpy.random.info-builtins:
#  []
#
# numpy.random.info-classes:
#  []
#
# numpy.random.info-functions:
#  []
#
# numpy.random.info-modules:
#  []
#
# numpy.random.info-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'depends', 'division', 'print_function']
#
# numpy.random.mtrand-builtins:
#  ['Lock', '_rand_bool', '_rand_int16', '_rand_int32', '_rand_int64', '_rand_int8', '_rand_uint16', '_rand_uint32', '_rand_uint64', '_rand_uint8', '_shape_from_size', 'beta', 'binomial', 'bytes', 'chisquare', 'choice', 'dirichlet', 'exponential', 'f', 'gamma', 'geometric', 'get_state', 'gumbel', 'hypergeometric', 'laplace', 'logistic', 'lognormal', 'logseries', 'multinomial', 'multivariate_normal', 'negative_binomial', 'noncentral_chisquare', 'noncentral_f', 'normal', 'pareto', 'permutation', 'poisson', 'power', 'rand', 'randint', 'randn', 'random_integers', 'random_sample', 'rayleigh', 'seed', 'set_state', 'shuffle', 'standard_cauchy', 'standard_exponential', 'standard_gamma', 'standard_normal', 'standard_t', 'triangular', 'uniform', 'vonmises', 'wald', 'weibull', 'zipf']
#
# numpy.random.mtrand-classes:
#  ['RandomState']
#
# numpy.random.mtrand-functions:
#  []
#
# numpy.random.mtrand-modules:
#  ['__builtins__', 'np', 'operator', 'warnings']
#
# numpy.random.mtrand-nofta:
#  ['__doc__', '__file__', '__name__', '__package__', '__test__', '_rand', '_randint_type']
#
# numpy.random.mtrand.np:
#  This exists but I cannot inspect it
#
# numpy.random.mtrand.operator:
#  This exists but I cannot inspect it
#
# numpy.random.mtrand.warnings:
#  This exists but I cannot inspect it
#
# numpy.random.np:
#  This exists but I cannot inspect it
#
# numpy.random.operator:
#  This exists but I cannot inspect it
#
# numpy.random.warnings:
#  This exists but I cannot inspect it
#
# numpy.rec:
#  This exists but I cannot inspect it
#
# numpy.testing-builtins:
#  []
#
# numpy.testing-classes:
#  ['IgnoreException', 'KnownFailureException', 'SkipTest', 'TestCase', 'Tester', 'clear_and_catch_warnings']
#
# numpy.testing-functions:
#  ['assert_', 'assert_allclose', 'assert_almost_equal', 'assert_approx_equal', 'assert_array_almost_equal', 'assert_array_almost_equal_nulp', 'assert_array_equal', 'assert_array_less', 'assert_array_max_ulp', 'assert_equal', 'assert_no_warnings', 'assert_raises', 'assert_raises_regex', 'assert_string_equal', 'assert_warns', 'build_err_msg', 'decorate_methods', 'jiffies', 'measure', 'memusage', 'print_assert_equal', 'raises', 'rand', 'run_module_suite', 'rundocs', 'runstring', 'tempdir', 'temppath']
#
# numpy.testing-modules:
#  ['dec', 'decorators', 'nosetester', 'utils']
#
# numpy.testing-nofta:
#  ['__builtins__', '__doc__', '__file__', '__name__', '__package__', '__path__', 'absolute_import', 'division', 'print_function', 'test', 'verbose']
#
# numpy.testing.dec:
#  This exists but I cannot inspect it
#
# numpy.testing.decorators-builtins:
#  []
#
# numpy.testing.decorators-classes:
#  ['SkipTest']
#
# numpy.testing.decorators-functions:
#  ['deprecated', 'knownfailureif', 'setastest', 'skipif', 'slow']
#
# numpy.testing.decorators-modules:
#  ['collections', 'warnings']
#
# numpy.testing.decorators-nofta:
#  ['__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'print_function']
#
# numpy.testing.decorators.collections:
#  This exists but I cannot inspect it
#
# numpy.testing.decorators.warnings:
#  This exists but I cannot inspect it
#
# numpy.testing.nosetester-builtins:
#  []
#
# numpy.testing.nosetester-classes:
#  ['NoseTester', 'basestring']
#
# numpy.testing.nosetester-functions:
#  ['_numpy_tester', 'get_package_name', 'import_nose', 'run_module_suite']
#
# numpy.testing.nosetester-modules:
#  ['np', 'os', 'sys', 'warnings']
#
# numpy.testing.nosetester-nofta:
#  ['__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'division', 'print_function']
#
# numpy.testing.nosetester.np:
#  This exists but I cannot inspect it
#
# numpy.testing.nosetester.os:
#  This exists but I cannot inspect it
#
# numpy.testing.nosetester.sys:
#  This exists but I cannot inspect it
#
# numpy.testing.nosetester.warnings:
#  This exists but I cannot inspect it
#
# numpy.testing.utils-builtins:
#  ['arange', 'empty']
#
# numpy.testing.utils-classes:
#  ['IgnoreException', 'KnownFailureException', 'KnownFailureTest', 'SkipTest', 'StringIO', 'WarningManager', 'WarningMessage', 'clear_and_catch_warnings', 'float32', 'ndarray', 'partial']
#
# numpy.testing.utils-functions:
#  ['_assert_no_warnings_context', '_assert_valid_refcount', '_assert_warns_context', '_gen_alignment_data', '_integer_repr', 'array_repr', 'assert_', 'assert_allclose', 'assert_almost_equal', 'assert_approx_equal', 'assert_array_almost_equal', 'assert_array_almost_equal_nulp', 'assert_array_compare', 'assert_array_equal', 'assert_array_less', 'assert_array_max_ulp', 'assert_equal', 'assert_no_warnings', 'assert_raises', 'assert_raises_regex', 'assert_string_equal', 'assert_warns', 'build_err_msg', 'decorate_methods', 'deprecate', 'gisfinite', 'gisinf', 'gisnan', 'import_nose', 'integer_repr', 'jiffies', 'measure', 'memusage', 'mkdtemp', 'mkstemp', 'nulp_diff', 'print_assert_equal', 'raises', 'rand', 'rundocs', 'runstring', 'tempdir', 'temppath']
#
# numpy.testing.utils-modules:
#  ['contextlib', 'operator', 'os', 're', 'shutil', 'sys', 'warnings']
#
# numpy.testing.utils-nofta:
#  ['__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'absolute_import', 'assert_raises_regex_impl', 'division', 'print_function', 'verbose']
#
# numpy.testing.utils.contextlib:
#  This exists but I cannot inspect it
#
# numpy.testing.utils.operator:
#  This exists but I cannot inspect it
#
# numpy.testing.utils.os:
#  This exists but I cannot inspect it
#
# numpy.testing.utils.re:
#  This exists but I cannot inspect it
#
# numpy.testing.utils.shutil:
#  This exists but I cannot inspect it
#
# numpy.testing.utils.sys:
#  This exists but I cannot inspect it
#
# numpy.testing.utils.warnings:
#  This exists but I cannot inspect it
#
# numpy.version-builtins:
#  []
#
# numpy.version-classes:
#  []
#
# numpy.version-functions:
#  []
#
# numpy.version-modules:
#  []
#
# numpy.version-nofta:
#  ['__builtins__', '__doc__', '__file__', '__name__', '__package__', 'full_version', 'git_revision', 'release', 'short_version', 'version']
#
# numpy.warnings:
#  This exists but I cannot inspect it

# %%
type(numpy.core.absolute.nin)
# Out:
# <type 'int'>
