# %% [markdown]
# # pyCustoms
#
# Matlab's functions are straightforward: One file per function, send in inputs and get outputs.  Python likes namespaces, modules, classes, objects, and packages so a lot of capability is buried deep in package hierarchies.  Combine that with documentation that varies from good to nonexistent and it can be tough to figure out what to invoke and how to invoke it.
#
# pyCustoms is experimental spaghetti code to inspect a package and figure out what links to what.  It uses importlib to programmatically load packages, dir to get information, and inspect to identify builtins, classes, functions, modules, and 'none of the above' aka nofta.
#
# pyCustoms returns a tree-like defaultdict of all results and a dependency list of tuples that show how modules, which seem to be the most important, link to one another.
#
# A separate draw_graph function takes the pyCustoms results and uses graphviz to generate a visual representation with some choice of engines, layout options, and the like.  The network view is amusing initially since the right choice of parameters can make it look like a fireworks display.  It takes a lot of zooming and panning to see the details and ultimately the prettyprinted defaultdict is faster and more useful.
#
# This code could be improved substantially, turned into a class, and so on but the results of this experiment don't justify that effort.
#
# Ravi Narasimhan <br>
# 3 June 2017

# %%
  
def pyCustoms(pkg_name, package_dictionary=None, dependency=None): 
    """
    pyCustoms inspects packages, walking down '.' module hierarchies and finding
    methods, functions, classes, builtins, and none-of-the-above (aka nofta)
    
    Input: Package name as a string, imports it if it exists, exits if it doesn't    
     
    Returns: 
    A dictionary, pkg_dict:
    - keys are <module name>-methods, functions, classes, builtins, or nofta
    - values are the names of the methods, functions, classes, builtins, or nofta
    
    and
    
    A module dependency list of tuples, dependency:
    - Each tuple is in the form (parent module, child module)
    - This shows the hierarchy of modules subject to limitations below
    
    pyCustoms ignores values prefixed with _ or __
    
    Some modules exist, can be inspected with dir(), but cannot be imported via
    the importlib.import_module.  pycustoms reports this as 'Uninspectable'
    and continues
    
    Usage: Enter at any level of a hierarchy
    
    ans = pyCustoms('numpy.random')  # Explore a numpy submodule
    
    for key in sorted(ans.iterkeys()):  # Print the dictionary
        print "{}:\\n {} \\n".format(key,ans[key])   
        
    --> Large output
    
    or 
    
    import pprint
    pprint.pprint(sorted(ans.iteritems()))
    
    Ravi Narasimhan  3 June 2017
    
    """
    
    import inspect
    import importlib
    import sys
    import functools
    import __main__
    from collections import defaultdict
    
    try:
        pkg = importlib.import_module(pkg_name)
    except ImportError:
        print "Can't find  {}.  Stopping".format(pkg_name)
        raise sys.exit(1)
        
    
    modules = []
    functions = []
    classes = []
    builtins = []
    noneoftheabove = []
    
    
    
    if not package_dictionary:
        pkg_dict=defaultdict(dict) # Create an empty dict if no dictionary is passed      
    else:
        pkg_dict = package_dictionary
    if not dependency:
        dependency = []
        
    for j in dir(pkg):
        if inspect.ismodule(getattr(pkg,j)):
             modules.append(j)
        elif inspect.isfunction((getattr(pkg,j))):
             functions.append(j)
        elif inspect.isclass((getattr(pkg,j))):
             classes.append(j)
        elif inspect.isbuiltin((getattr(pkg,j))):
             builtins.append(j)
        else:
             noneoftheabove.append(j)

    pkg_dict[pkg_name]['builtins'] = builtins
    pkg_dict[pkg_name]['modules'] = modules
    pkg_dict[pkg_name]['classes'] = classes
    pkg_dict[pkg_name]['functions'] = functions
    pkg_dict[pkg_name]['nofta'] = noneoftheabove      

    for k in modules:
        if not k.startswith('_'): # Let's skip the unders and dunders
            # importlib can't open everything for some reason
            # trap errors and skip
            # getattr and reduce might be able to get past this problem
            # but there could be circular references as well as further
            # clutter
            try:
                pkg = importlib.import_module(pkg_name+'.'+k)
            except ImportError:                
                pkg_dict[pkg_name+'.'+k] = r'Uninspectable'
                dependency.append((pkg_name, pkg_name+'.'+k)) 
                continue
            dependency.append((pkg_name, pkg_name+'.'+k)) 
            pyCustoms(pkg_name+'.'+k,pkg_dict, dependency)
    # print dependency        
    return pkg_dict, dependency

# %%
# Let's try to visualize the network.  The engine and
# format options are the most important.  Some choices
# return a result worth looking at.  Others either don't or
# hang, especially on the complicated packages like numpy
# circo is a usable engine although it doesn't support many
# of the attributes that graphviz allows like fontsize

def draw_graph (ans, dep):
    from graphviz import Digraph, Graph
    u = Digraph(package, filename = package+'.gv', 
                engine = 'circo', format = 'pdf')

    # Setting an explicit size usually makes for a loadable PDF
    # The adjustable scale seems to help but I can't be sure that it does
    # For numpy and circo, u.attr(size='36,36'), u.graph_attr.update({'scale':'0.66'})
    # gives a pdf that loads in finite time and allows navigation.  Full redraws
    # can be slow, though.  Acrobat DC is surprisingly better than Skim
    # Taking out the shapes around nodes speeds things up.  Perhaps
    # the graphviz primitives have to be interpreted one-by-one by the 
    # PDF reader.  I had very little success with svg output.  The 
    # nodes and edges are so faint, they are almost impossible to read.
    # The size attributes for svg are not the same as pdf and regardless of
    # settings, Firefox, Safari, Brave, and other browsers had great 
    # trouble rendering the files

    # Set the pdf page size in in x in
    u.attr(size='36,36')

    # This is how to change the scale after layout.  Let's leave it in in case
    # we need to do it 
    u.graph_attr.update({'scale':'1'})

    # Jerry-rig the fontsize to make the plot readable
    # circo doesn't recognize this, though
    top_level_fontsize = 24 

    # Let's make a rudimentary style sheet so we can experiment
    # I originally had different shapes for the _nodes but I think this makes
    # for very slow PDF performance.  
    module_node = {'color':'blue', 'shape':'box', 'fontsize':str(top_level_fontsize*1)}
    module_edge = {'color':'blue', 'style':'solid', 'penwidth':'4'}
    builtins_node = {'color':'red', 'shape':'none', 'fontsize':str(top_level_fontsize*1)}
    builtins_edge = {'color':'red', 'style':'dashed', 'penwidth':'1'}
    classes_node = {'color':'gold', 'shape':'none', 'fontsize':str(top_level_fontsize*1)}
    classes_edge = {'color':'gold', 'style':'dashed', 'penwidth':'1'}
    functions_node = {'color':'purple', 'shape':'none', 'fontsize':str(top_level_fontsize*1)}
    functions_edge = {'color':'purple', 'style':'dashed', 'penwidth':'1'}
    nofta_node = {'color':'black', 'shape':'none', 'fontsize':str(top_level_fontsize*1)}
    nofta_edge = {'color':'black', 'style':'dashed', 'penwidth':'1'}

    # First:
    # dep contains the module-to-module connections.  Let's
    # generate the module nodes and connect them using the style
    # information in module_node and module_edge

    for j in dep: # dependencies show module to module links

        u.node(j[0], **module_node )
        u.node(j[1], **module_node )
        u.edge(j[0], j[1], **module_edge)

    # Second:
    # We need to hang the contents of each module onto its node
    # We only want to do this once so we need a list of unique nodes
    # dep is a nested list of tuples so let's find some code on Stack
    # Overflow to flatten a list:
    # https://stackoverflow.com/questions/952914/making-a-flat-list-out-of-list-of-lists-in-python
    # and then use Python's set functionto keep only the unique items

    dep_unique_modules=set([item for sublist in dep for item in sublist]) # List of unique modules

    # Some packages like Python's math don't have any submodules. Or,
    # we may start down in a hierarchy where there are no submodules
    # to the requested package.  In this case, dep would be an empty
    # set and we need to ensure at minimum to hange the builtins, classes,
    # etc. of the requested package on its node

    # If there are no unique modules, we will use the requested package
    # as the unique module

    if dep_unique_modules == set():
        dep_unique_modules = [package]

    # Now, let's look at each unique module and hang the builtins,
    # classes, functions, and nofta onto the pertinent node

    for k in dep_unique_modules:
        u.node(k + '-'+ 'builtins', **builtins_node)
        u.edge(k,k + '-'+ 'builtins', **builtins_edge)

    # Note that pycustoms returns the string 'Uninspectable' if it
    # can't open something for whatever reason.  In this case, we
    # get a string as a dict's value as opposed to another dict.
    # My solution is to ignore the Uninspectable items and only
    # process those keys that return a dict
    # I'm leaving this as spahetti code since it was very helpful
    # during debugging to have it all written out.  I have learned what
    # I want to learn from this exercise and there's no reason to
    # make this pretty or Pythonic

        if type(ans[k]) == dict:
            for l in ans[k]['builtins']:  
                u.node(k + '.' + l , **builtins_node)
                u.edge(k + '-'+ 'builtins', k + '.' + l , **builtins_edge)
        u.node(k + '-'+ 'classes', **classes_node)
        u.edge(k,k + '-'+ 'classes', **classes_edge)
        if type(ans[k]) == dict:
            for l in ans[k]['classes']:  
                u.node(k + '.' + l , **classes_node)
                u.edge(k + '-'+ 'classes', k + '.' + l, **classes_edge)
        u.node(k + '-'+ 'functions', **functions_node)
        u.edge(k,k + '-'+ 'functions', **functions_edge)
        if type(ans[k]) == dict:
            for l in ans[k]['functions']:  
                u.node(k + '.' + l , **functions_node)
                u.edge(k + '-'+ 'functions', k + '.' + l , **functions_edge)
        u.node(k + '-'+ 'nofta', **nofta_node)
        u.edge(k,k + '-'+ 'nofta', **nofta_edge)
        if type(ans[k]) == dict:
            for l in ans[k]['nofta']:  
                u.node(k + '.' + l , **nofta_node)
                u.edge(k + '-'+ 'nofta', k + '.' + l, **nofta_edge)

    # Save a text file with the graph data for graphviz, Gephi, or some other
    # code to process
    u.save()

    # Spawn a viewer if one exists for the output filetype (pdf, svg, ...)
    u.view()

    # Display the graph as an image in an Output cell.  Not very useful, especially
    # for large graphs.  No zoom, pan, or other features
    # u

# %%
# Let's pick a package...
package = 'numpy'

#... invoke pycustoms and get the dictionary of links
# and the connections of the modules, respectively
ans, dep = pyCustoms(package)

# Pass the dictionary with the package breakdown
# along with the the module dependencies to the drawing routine
draw_graph(ans, dep)

# %%
# Let's look at the defaultdict returned by pyCustoms
import pprint
pprint.pprint(sorted(ans.items()))
# Out:
# [('numpy',
#   {'builtins': ['add_docstring',
#                 'add_newdoc_ufunc',
#                 'arange',
#                 'array',
#                 'bincount',
#                 'busday_count',
#                 'busday_offset',
#                 'can_cast',
#                 'compare_chararrays',
#                 'concatenate',
#                 'copyto',
#                 'count_nonzero',
#                 'datetime_as_string',
#                 'datetime_data',
#                 'digitize',
#                 'dot',
#                 'einsum',
#                 'empty',
#                 'empty_like',
#                 'fastCopyAndTranspose',
#                 'frombuffer',
#                 'fromfile',
#                 'fromiter',
#                 'frompyfunc',
#                 'fromstring',
#                 'getbuffer',
#                 'geterrobj',
#                 'inner',
#                 'int_asbuffer',
#                 'is_busday',
#                 'lexsort',
#                 'loads',
#                 'matmul',
#                 'may_share_memory',
#                 'min_scalar_type',
#                 'nested_iters',
#                 'newbuffer',
#                 'packbits',
#                 'promote_types',
#                 'putmask',
#                 'ravel_multi_index',
#                 'result_type',
#                 'set_numeric_ops',
#                 'seterrobj',
#                 'shares_memory',
#                 'unpackbits',
#                 'unravel_index',
#                 'vdot',
#                 'where',
#                 'zeros'],
#    'classes': ['ComplexWarning',
#                'DataSource',
#                'MachAr',
#                'ModuleDeprecationWarning',
#                'PackageLoader',
#                'RankWarning',
#                'Tester',
#                'TooHardError',
#                'VisibleDeprecationWarning',
#                '_NoValue',
#                'bool',
#                'bool8',
#                'bool_',
#                'broadcast',
#                'busdaycalendar',
#                'byte',
#                'bytes_',
#                'cdouble',
#                'cfloat',
#                'character',
#                'chararray',
#                'clongdouble',
#                'clongfloat',
#                'complex',
#                'complex128',
#                'complex256',
#                'complex64',
#                'complex_',
#                'complexfloating',
#                'csingle',
#                'datetime64',
#                'double',
#                'dtype',
#                'errstate',
#                'finfo',
#                'flatiter',
#                'flexible',
#                'float',
#                'float128',
#                'float16',
#                'float32',
#                'float64',
#                'float_',
#                'floating',
#                'format_parser',
#                'generic',
#                'half',
#                'iinfo',
#                'inexact',
#                'int',
#                'int0',
#                'int16',
#                'int32',
#                'int64',
#                'int8',
#                'int_',
#                'intc',
#                'integer',
#                'intp',
#                'long',
#                'longcomplex',
#                'longdouble',
#                'longfloat',
#                'longlong',
#                'matrix',
#                'memmap',
#                'ndarray',
#                'ndenumerate',
#                'ndindex',
#                'nditer',
#                'number',
#                'object',
#                'object0',
#                'object_',
#                'poly1d',
#                'recarray',
#                'record',
#                'short',
#                'signedinteger',
#                'single',
#                'singlecomplex',
#                'str',
#                'str_',
#                'string0',
#                'string_',
#                'timedelta64',
#                'ubyte',
#                'ufunc',
#                'uint',
#                'uint0',
#                'uint16',
#                'uint32',
#                'uint64',
#                'uint8',
#                'uintc',
#                'uintp',
#                'ulonglong',
#                'unicode',
#                'unicode0',
#                'unicode_',
#                'unsignedinteger',
#                'ushort',
#                'vectorize',
#                'void',
#                'void0'],
#    'functions': ['add_newdoc',
#                  'alen',
#                  'all',
#                  'allclose',
#                  'alltrue',
#                  'alterdot',
#                  'amax',
#                  'amin',
#                  'angle',
#                  'any',
#                  'append',
#                  'apply_along_axis',
#                  'apply_over_axes',
#                  'argmax',
#                  'argmin',
#                  'argpartition',
#                  'argsort',
#                  'argwhere',
#                  'around',
#                  'array2string',
#                  'array_equal',
#                  'array_equiv',
#                  'array_repr',
#                  'array_split',
#                  'array_str',
#                  'asanyarray',
#                  'asarray',
#                  'asarray_chkfinite',
#                  'ascontiguousarray',
#                  'asfarray',
#                  'asfortranarray',
#                  'asmatrix',
#                  'asscalar',
#                  'atleast_1d',
#                  'atleast_2d',
#                  'atleast_3d',
#                  'average',
#                  'bartlett',
#                  'base_repr',
#                  'binary_repr',
#                  'blackman',
#                  'bmat',
#                  'broadcast_arrays',
#                  'broadcast_to',
#                  'byte_bounds',
#                  'choose',
#                  'clip',
#                  'column_stack',
#                  'common_type',
#                  'compress',
#                  'convolve',
#                  'copy',
#                  'corrcoef',
#                  'correlate',
#                  'cov',
#                  'cross',
#                  'cumprod',
#                  'cumproduct',
#                  'cumsum',
#                  'delete',
#                  'deprecate',
#                  'deprecate_with_doc',
#                  'diag',
#                  'diag_indices',
#                  'diag_indices_from',
#                  'diagflat',
#                  'diagonal',
#                  'diff',
#                  'disp',
#                  'dsplit',
#                  'dstack',
#                  'ediff1d',
#                  'expand_dims',
#                  'extract',
#                  'eye',
#                  'fill_diagonal',
#                  'find_common_type',
#                  'fix',
#                  'flatnonzero',
#                  'fliplr',
#                  'flipud',
#                  'fromfunction',
#                  'fromregex',
#                  'full',
#                  'full_like',
#                  'fv',
#                  'genfromtxt',
#                  'get_array_wrap',
#                  'get_include',
#                  'get_printoptions',
#                  'getbufsize',
#                  'geterr',
#                  'geterrcall',
#                  'gradient',
#                  'hamming',
#                  'hanning',
#                  'histogram',
#                  'histogram2d',
#                  'histogramdd',
#                  'hsplit',
#                  'hstack',
#                  'i0',
#                  'identity',
#                  'imag',
#                  'in1d',
#                  'indices',
#                  'info',
#                  'insert',
#                  'interp',
#                  'intersect1d',
#                  'ipmt',
#                  'irr',
#                  'isclose',
#                  'iscomplex',
#                  'iscomplexobj',
#                  'isfortran',
#                  'isneginf',
#                  'isposinf',
#                  'isreal',
#                  'isrealobj',
#                  'isscalar',
#                  'issctype',
#                  'issubclass_',
#                  'issubdtype',
#                  'issubsctype',
#                  'iterable',
#                  'ix_',
#                  'kaiser',
#                  'kron',
#                  'linspace',
#                  'load',
#                  'loadtxt',
#                  'logspace',
#                  'lookfor',
#                  'mafromtxt',
#                  'mask_indices',
#                  'mat',
#                  'max',
#                  'maximum_sctype',
#                  'mean',
#                  'median',
#                  'meshgrid',
#                  'min',
#                  'mintypecode',
#                  'mirr',
#                  'moveaxis',
#                  'msort',
#                  'nan_to_num',
#                  'nanargmax',
#                  'nanargmin',
#                  'nanmax',
#                  'nanmean',
#                  'nanmedian',
#                  'nanmin',
#                  'nanpercentile',
#                  'nanprod',
#                  'nanstd',
#                  'nansum',
#                  'nanvar',
#                  'ndfromtxt',
#                  'ndim',
#                  'nonzero',
#                  'nper',
#                  'npv',
#                  'obj2sctype',
#                  'ones',
#                  'ones_like',
#                  'outer',
#                  'pad',
#                  'partition',
#                  'percentile',
#                  'piecewise',
#                  'pkgload',
#                  'place',
#                  'pmt',
#                  'poly',
#                  'polyadd',
#                  'polyder',
#                  'polydiv',
#                  'polyfit',
#                  'polyint',
#                  'polymul',
#                  'polysub',
#                  'polyval',
#                  'ppmt',
#                  'prod',
#                  'product',
#                  'ptp',
#                  'put',
#                  'pv',
#                  'rank',
#                  'rate',
#                  'ravel',
#                  'real',
#                  'real_if_close',
#                  'recfromcsv',
#                  'recfromtxt',
#                  'repeat',
#                  'require',
#                  'reshape',
#                  'resize',
#                  'restoredot',
#                  'roll',
#                  'rollaxis',
#                  'roots',
#                  'rot90',
#                  'round',
#                  'round_',
#                  'row_stack',
#                  'safe_eval',
#                  'save',
#                  'savetxt',
#                  'savez',
#                  'savez_compressed',
#                  'sctype2char',
#                  'searchsorted',
#                  'select',
#                  'set_printoptions',
#                  'set_string_function',
#                  'setbufsize',
#                  'setdiff1d',
#                  'seterr',
#                  'seterrcall',
#                  'setxor1d',
#                  'shape',
#                  'show_config',
#                  'sinc',
#                  'size',
#                  'sometrue',
#                  'sort',
#                  'sort_complex',
#                  'source',
#                  'split',
#                  'squeeze',
#                  'stack',
#                  'std',
#                  'sum',
#                  'swapaxes',
#                  'take',
#                  'tensordot',
#                  'tile',
#                  'trace',
#                  'transpose',
#                  'trapz',
#                  'tri',
#                  'tril',
#                  'tril_indices',
#                  'tril_indices_from',
#                  'trim_zeros',
#                  'triu',
#                  'triu_indices',
#                  'triu_indices_from',
#                  'typename',
#                  'union1d',
#                  'unique',
#                  'unwrap',
#                  'vander',
#                  'var',
#                  'vsplit',
#                  'vstack',
#                  'who',
#                  'zeros_like'],
#    'modules': ['__config__',
#                '_globals',
#                '_import_tools',
#                '_mat',
#                'add_newdocs',
#                'char',
#                'compat',
#                'core',
#                'ctypeslib',
#                'emath',
#                'fft',
#                'lib',
#                'linalg',
#                'ma',
#                'math',
#                'matrixlib',
#                'polynomial',
#                'random',
#                'rec',
#                'testing',
#                'version',
#                'warnings'],
#    'nofta': ['ALLOW_THREADS',
#              'BUFSIZE',
#              'CLIP',
#              'ERR_CALL',
#              'ERR_DEFAULT',
#              'ERR_IGNORE',
#              'ERR_LOG',
#              'ERR_PRINT',
#              'ERR_RAISE',
#              'ERR_WARN',
#              'FLOATING_POINT_SUPPORT',
#              'FPE_DIVIDEBYZERO',
#              'FPE_INVALID',
#              'FPE_OVERFLOW',
#              'FPE_UNDERFLOW',
#              'False_',
#              'Inf',
#              'Infinity',
#              'MAXDIMS',
#              'MAY_SHARE_BOUNDS',
#              'MAY_SHARE_EXACT',
#              'NAN',
#              'NINF',
#              'NZERO',
#              'NaN',
#              'PINF',
#              'PZERO',
#              'RAISE',
#              'SHIFT_DIVIDEBYZERO',
#              'SHIFT_INVALID',
#              'SHIFT_OVERFLOW',
#              'SHIFT_UNDERFLOW',
#              'ScalarType',
#              'True_',
#              'UFUNC_BUFSIZE_DEFAULT',
#              'UFUNC_PYVALS_NAME',
#              'WRAP',
#              '__NUMPY_SETUP__',
#              '__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__git_revision__',
#              '__mkl_version__',
#              '__name__',
#              '__package__',
#              '__path__',
#              '__version__',
#              'abs',
#              'absolute',
#              'absolute_import',
#              'add',
#              'arccos',
#              'arccosh',
#              'arcsin',
#              'arcsinh',
#              'arctan',
#              'arctan2',
#              'arctanh',
#              'bench',
#              'bitwise_and',
#              'bitwise_not',
#              'bitwise_or',
#              'bitwise_xor',
#              'c_',
#              'cast',
#              'cbrt',
#              'ceil',
#              'conj',
#              'conjugate',
#              'copysign',
#              'cos',
#              'cosh',
#              'deg2rad',
#              'degrees',
#              'divide',
#              'division',
#              'e',
#              'equal',
#              'euler_gamma',
#              'exp',
#              'exp2',
#              'expm1',
#              'fabs',
#              'floor',
#              'floor_divide',
#              'fmax',
#              'fmin',
#              'fmod',
#              'frexp',
#              'greater',
#              'greater_equal',
#              'hypot',
#              'index_exp',
#              'inf',
#              'infty',
#              'invert',
#              'isfinite',
#              'isinf',
#              'isnan',
#              'ldexp',
#              'left_shift',
#              'less',
#              'less_equal',
#              'little_endian',
#              'log',
#              'log10',
#              'log1p',
#              'log2',
#              'logaddexp',
#              'logaddexp2',
#              'logical_and',
#              'logical_not',
#              'logical_or',
#              'logical_xor',
#              'maximum',
#              'mgrid',
#              'minimum',
#              'mod',
#              'modf',
#              'multiply',
#              'nan',
#              'nbytes',
#              'negative',
#              'newaxis',
#              'nextafter',
#              'not_equal',
#              'numarray',
#              'ogrid',
#              'oldnumeric',
#              'pi',
#              'power',
#              'print_function',
#              'r_',
#              'rad2deg',
#              'radians',
#              'reciprocal',
#              'remainder',
#              'right_shift',
#              'rint',
#              's_',
#              'sctypeDict',
#              'sctypeNA',
#              'sctypes',
#              'sign',
#              'signbit',
#              'sin',
#              'sinh',
#              'spacing',
#              'sqrt',
#              'square',
#              'subtract',
#              'tan',
#              'tanh',
#              'test',
#              'true_divide',
#              'trunc',
#              'typeDict',
#              'typeNA',
#              'typecodes']}),
#  ('numpy.add_newdocs',
#   {'builtins': [],
#    'classes': [],
#    'functions': ['add_newdoc'],
#    'modules': [],
#    'nofta': ['__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              'absolute_import',
#              'division',
#              'print_function',
#              'tobytesdoc']}),
#  ('numpy.char', 'Uninspectable'),
#  ('numpy.compat',
#   {'builtins': [],
#    'classes': ['asbytes', 'asstr', 'basestring', 'bytes', 'long', 'unicode'],
#    'functions': ['asbytes_nested',
#                  'asunicode',
#                  'asunicode_nested',
#                  'formatargspec',
#                  'getargspec',
#                  'getexception',
#                  'isfileobj',
#                  'npy_load_module',
#                  'open_latin1',
#                  'sixu'],
#    'modules': ['_inspect', 'py3k'],
#    'nofta': ['__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              '__path__',
#              'absolute_import',
#              'division',
#              'integer_types',
#              'print_function',
#              'strchar']}),
#  ('numpy.compat.py3k',
#   {'builtins': [],
#    'classes': ['asbytes', 'asstr', 'basestring', 'bytes', 'long', 'unicode'],
#    'functions': ['asbytes_nested',
#                  'asunicode',
#                  'asunicode_nested',
#                  'getexception',
#                  'isfileobj',
#                  'npy_load_module',
#                  'open_latin1',
#                  'sixu'],
#    'modules': ['sys'],
#    'nofta': ['__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              'absolute_import',
#              'division',
#              'integer_types',
#              'print_function',
#              'strchar']}),
#  ('numpy.compat.py3k.sys', 'Uninspectable'),
#  ('numpy.core',
#   {'builtins': ['arange',
#                 'array',
#                 'busday_count',
#                 'busday_offset',
#                 'can_cast',
#                 'compare_chararrays',
#                 'concatenate',
#                 'copyto',
#                 'count_nonzero',
#                 'datetime_as_string',
#                 'datetime_data',
#                 'dot',
#                 'einsum',
#                 'empty',
#                 'empty_like',
#                 'fastCopyAndTranspose',
#                 'frombuffer',
#                 'fromfile',
#                 'fromiter',
#                 'frompyfunc',
#                 'fromstring',
#                 'getbuffer',
#                 'geterrobj',
#                 'inner',
#                 'int_asbuffer',
#                 'is_busday',
#                 'lexsort',
#                 'loads',
#                 'matmul',
#                 'may_share_memory',
#                 'min_scalar_type',
#                 'nested_iters',
#                 'newbuffer',
#                 'promote_types',
#                 'putmask',
#                 'result_type',
#                 'set_numeric_ops',
#                 'seterrobj',
#                 'shares_memory',
#                 'vdot',
#                 'where',
#                 'zeros'],
#    'classes': ['ComplexWarning',
#                'MachAr',
#                'TooHardError',
#                'bool8',
#                'bool_',
#                'broadcast',
#                'busdaycalendar',
#                'byte',
#                'bytes_',
#                'cdouble',
#                'cfloat',
#                'character',
#                'chararray',
#                'clongdouble',
#                'clongfloat',
#                'complex128',
#                'complex256',
#                'complex64',
#                'complex_',
#                'complexfloating',
#                'csingle',
#                'datetime64',
#                'double',
#                'dtype',
#                'errstate',
#                'finfo',
#                'flatiter',
#                'flexible',
#                'float128',
#                'float16',
#                'float32',
#                'float64',
#                'float_',
#                'floating',
#                'format_parser',
#                'generic',
#                'half',
#                'iinfo',
#                'inexact',
#                'int0',
#                'int16',
#                'int32',
#                'int64',
#                'int8',
#                'int_',
#                'intc',
#                'integer',
#                'intp',
#                'longcomplex',
#                'longdouble',
#                'longfloat',
#                'longlong',
#                'memmap',
#                'ndarray',
#                'nditer',
#                'number',
#                'object0',
#                'object_',
#                'recarray',
#                'record',
#                'short',
#                'signedinteger',
#                'single',
#                'singlecomplex',
#                'str_',
#                'string0',
#                'string_',
#                'timedelta64',
#                'ubyte',
#                'ufunc',
#                'uint',
#                'uint0',
#                'uint16',
#                'uint32',
#                'uint64',
#                'uint8',
#                'uintc',
#                'uintp',
#                'ulonglong',
#                'unicode0',
#                'unicode_',
#                'unsignedinteger',
#                'ushort',
#                'void',
#                'void0'],
#    'functions': ['_numpy_tester',
#                  '_ufunc_reconstruct',
#                  'alen',
#                  'all',
#                  'allclose',
#                  'alltrue',
#                  'alterdot',
#                  'amax',
#                  'amin',
#                  'any',
#                  'argmax',
#                  'argmin',
#                  'argpartition',
#                  'argsort',
#                  'argwhere',
#                  'around',
#                  'array2string',
#                  'array_equal',
#                  'array_equiv',
#                  'array_repr',
#                  'array_str',
#                  'asanyarray',
#                  'asarray',
#                  'ascontiguousarray',
#                  'asfortranarray',
#                  'atleast_1d',
#                  'atleast_2d',
#                  'atleast_3d',
#                  'base_repr',
#                  'binary_repr',
#                  'choose',
#                  'clip',
#                  'compress',
#                  'convolve',
#                  'correlate',
#                  'cross',
#                  'cumprod',
#                  'cumproduct',
#                  'cumsum',
#                  'diagonal',
#                  'find_common_type',
#                  'flatnonzero',
#                  'fromfunction',
#                  'full',
#                  'full_like',
#                  'get_printoptions',
#                  'getbufsize',
#                  'geterr',
#                  'geterrcall',
#                  'hstack',
#                  'identity',
#                  'indices',
#                  'isclose',
#                  'isfortran',
#                  'isscalar',
#                  'issctype',
#                  'issubdtype',
#                  'linspace',
#                  'load',
#                  'logspace',
#                  'max',
#                  'maximum_sctype',
#                  'mean',
#                  'min',
#                  'moveaxis',
#                  'ndim',
#                  'nonzero',
#                  'obj2sctype',
#                  'ones',
#                  'ones_like',
#                  'outer',
#                  'partition',
#                  'prod',
#                  'product',
#                  'ptp',
#                  'put',
#                  'rank',
#                  'ravel',
#                  'repeat',
#                  'require',
#                  'reshape',
#                  'resize',
#                  'restoredot',
#                  'roll',
#                  'rollaxis',
#                  'round',
#                  'round_',
#                  'sctype2char',
#                  'searchsorted',
#                  'set_printoptions',
#                  'set_string_function',
#                  'setbufsize',
#                  'seterr',
#                  'seterrcall',
#                  'shape',
#                  'size',
#                  'sometrue',
#                  'sort',
#                  'squeeze',
#                  'stack',
#                  'std',
#                  'sum',
#                  'swapaxes',
#                  'take',
#                  'tensordot',
#                  'trace',
#                  'transpose',
#                  'var',
#                  'vstack',
#                  'zeros_like'],
#    'modules': ['_internal',
#                '_methods',
#                'arrayprint',
#                'char',
#                'defchararray',
#                'fromnumeric',
#                'function_base',
#                'getlimits',
#                'info',
#                'machar',
#                'multiarray',
#                'numeric',
#                'numerictypes',
#                'rec',
#                'records',
#                'shape_base',
#                'umath'],
#    'nofta': ['ALLOW_THREADS',
#              'BUFSIZE',
#              'CLIP',
#              'ERR_CALL',
#              'ERR_DEFAULT',
#              'ERR_IGNORE',
#              'ERR_LOG',
#              'ERR_PRINT',
#              'ERR_RAISE',
#              'ERR_WARN',
#              'FLOATING_POINT_SUPPORT',
#              'FPE_DIVIDEBYZERO',
#              'FPE_INVALID',
#              'FPE_OVERFLOW',
#              'FPE_UNDERFLOW',
#              'False_',
#              'Inf',
#              'Infinity',
#              'MAXDIMS',
#              'MAY_SHARE_BOUNDS',
#              'MAY_SHARE_EXACT',
#              'NAN',
#              'NINF',
#              'NZERO',
#              'NaN',
#              'PINF',
#              'PZERO',
#              'RAISE',
#              'SHIFT_DIVIDEBYZERO',
#              'SHIFT_INVALID',
#              'SHIFT_OVERFLOW',
#              'SHIFT_UNDERFLOW',
#              'ScalarType',
#              'True_',
#              'UFUNC_BUFSIZE_DEFAULT',
#              'UFUNC_PYVALS_NAME',
#              'WRAP',
#              '__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              '__path__',
#              '__version__',
#              'abs',
#              'absolute',
#              'absolute_import',
#              'add',
#              'arccos',
#              'arccosh',
#              'arcsin',
#              'arcsinh',
#              'arctan',
#              'arctan2',
#              'arctanh',
#              'bench',
#              'bitwise_and',
#              'bitwise_not',
#              'bitwise_or',
#              'bitwise_xor',
#              'cast',
#              'cbrt',
#              'ceil',
#              'conj',
#              'conjugate',
#              'copysign',
#              'cos',
#              'cosh',
#              'deg2rad',
#              'degrees',
#              'divide',
#              'division',
#              'e',
#              'equal',
#              'euler_gamma',
#              'exp',
#              'exp2',
#              'expm1',
#              'fabs',
#              'floor',
#              'floor_divide',
#              'fmax',
#              'fmin',
#              'fmod',
#              'frexp',
#              'greater',
#              'greater_equal',
#              'hypot',
#              'inf',
#              'infty',
#              'invert',
#              'isfinite',
#              'isinf',
#              'isnan',
#              'ldexp',
#              'left_shift',
#              'less',
#              'less_equal',
#              'little_endian',
#              'log',
#              'log10',
#              'log1p',
#              'log2',
#              'logaddexp',
#              'logaddexp2',
#              'logical_and',
#              'logical_not',
#              'logical_or',
#              'logical_xor',
#              'maximum',
#              'minimum',
#              'mod',
#              'modf',
#              'multiply',
#              'nan',
#              'nbytes',
#              'negative',
#              'newaxis',
#              'nextafter',
#              'not_equal',
#              'pi',
#              'power',
#              'print_function',
#              'rad2deg',
#              'radians',
#              'reciprocal',
#              'remainder',
#              'right_shift',
#              'rint',
#              'sctypeDict',
#              'sctypeNA',
#              'sctypes',
#              'sign',
#              'signbit',
#              'sin',
#              'sinh',
#              'spacing',
#              'sqrt',
#              'square',
#              'subtract',
#              'tan',
#              'tanh',
#              'test',
#              'true_divide',
#              'trunc',
#              'typeDict',
#              'typeNA',
#              'typecodes']}),
#  ('numpy.core.arrayprint',
#   {'builtins': ['array',
#                 'datetime_as_string',
#                 'datetime_data',
#                 'format_longfloat',
#                 'reduce'],
#    'classes': ['ComplexFormat',
#                'DatetimeFormat',
#                'FloatFormat',
#                'IntegerFormat',
#                'LongComplexFormat',
#                'LongFloatFormat',
#                'TimedeltaFormat'],
#    'functions': ['_array2string',
#                  '_boolFormatter',
#                  '_convert_arrays',
#                  '_digits',
#                  '_extendLine',
#                  '_formatArray',
#                  '_leading_trailing',
#                  'array2string',
#                  'asarray',
#                  'get_printoptions',
#                  'product',
#                  'ravel',
#                  'repr_format',
#                  'set_printoptions'],
#    'modules': ['_nt', 'sys'],
#    'nofta': ['_MAXINT',
#              '_MININT',
#              '__all__',
#              '__builtins__',
#              '__doc__',
#              '__docformat__',
#              '__file__',
#              '__name__',
#              '__package__',
#              '_float_output_precision',
#              '_float_output_suppress_small',
#              '_formatter',
#              '_inf_str',
#              '_line_width',
#              '_nan_str',
#              '_summaryEdgeItems',
#              '_summaryThreshold',
#              'absolute',
#              'absolute_import',
#              'division',
#              'isinf',
#              'isnan',
#              'maximum',
#              'minimum',
#              'not_equal',
#              'print_function']}),
#  ('numpy.core.arrayprint.sys', 'Uninspectable'),
#  ('numpy.core.char', 'Uninspectable'),
#  ('numpy.core.defchararray',
#   {'builtins': ['_len', '_vec_string', 'compare_chararrays', 'narray'],
#    'classes': ['_bytes',
#                '_unicode',
#                'asbytes',
#                'bool_',
#                'character',
#                'chararray',
#                'integer',
#                'long',
#                'ndarray',
#                'object_',
#                'string_',
#                'unicode_'],
#    'functions': ['_clean_args',
#                  '_get_num_chars',
#                  '_to_string_or_unicode_array',
#                  '_use_unicode',
#                  'add',
#                  'array',
#                  'asarray',
#                  'capitalize',
#                  'center',
#                  'count',
#                  'decode',
#                  'encode',
#                  'endswith',
#                  'equal',
#                  'expandtabs',
#                  'find',
#                  'greater',
#                  'greater_equal',
#                  'index',
#                  'isalnum',
#                  'isalpha',
#                  'isdecimal',
#                  'isdigit',
#                  'islower',
#                  'isnumeric',
#                  'isspace',
#                  'istitle',
#                  'isupper',
#                  'join',
#                  'less',
#                  'less_equal',
#                  'ljust',
#                  'lower',
#                  'lstrip',
#                  'mod',
#                  'multiply',
#                  'not_equal',
#                  'partition',
#                  'replace',
#                  'rfind',
#                  'rindex',
#                  'rjust',
#                  'rpartition',
#                  'rsplit',
#                  'rstrip',
#                  'split',
#                  'splitlines',
#                  'startswith',
#                  'str_len',
#                  'strip',
#                  'swapcase',
#                  'title',
#                  'translate',
#                  'upper',
#                  'zfill'],
#    'modules': ['numpy', 'sys'],
#    'nofta': ['__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              '_globalvar',
#              'absolute_import',
#              'division',
#              'print_function']}),
#  ('numpy.core.defchararray.numpy', 'Uninspectable'),
#  ('numpy.core.defchararray.sys', 'Uninspectable'),
#  ('numpy.core.fromnumeric',
#   {'builtins': ['_sum_', 'array', 'concatenate'],
#    'classes': ['VisibleDeprecationWarning', '_gentype'],
#    'functions': ['_dt_',
#                  '_wrapit',
#                  'alen',
#                  'all',
#                  'alltrue',
#                  'amax',
#                  'amin',
#                  'any',
#                  'argmax',
#                  'argmin',
#                  'argpartition',
#                  'argsort',
#                  'around',
#                  'asanyarray',
#                  'asarray',
#                  'choose',
#                  'clip',
#                  'compress',
#                  'cumprod',
#                  'cumproduct',
#                  'cumsum',
#                  'diagonal',
#                  'mean',
#                  'ndim',
#                  'nonzero',
#                  'partition',
#                  'prod',
#                  'product',
#                  'ptp',
#                  'put',
#                  'rank',
#                  'ravel',
#                  'repeat',
#                  'reshape',
#                  'resize',
#                  'round_',
#                  'searchsorted',
#                  'shape',
#                  'size',
#                  'sometrue',
#                  'sort',
#                  'squeeze',
#                  'std',
#                  'sum',
#                  'swapaxes',
#                  'take',
#                  'trace',
#                  'transpose',
#                  'var'],
#    'modules': ['_methods', 'mu', 'np', 'nt', 'types', 'um', 'warnings'],
#    'nofta': ['__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              'absolute_import',
#              'division',
#              'print_function']}),
#  ('numpy.core.fromnumeric.mu', 'Uninspectable'),
#  ('numpy.core.fromnumeric.np', 'Uninspectable'),
#  ('numpy.core.fromnumeric.nt', 'Uninspectable'),
#  ('numpy.core.fromnumeric.types', 'Uninspectable'),
#  ('numpy.core.fromnumeric.um', 'Uninspectable'),
#  ('numpy.core.fromnumeric.warnings', 'Uninspectable'),
#  ('numpy.core.function_base',
#   {'builtins': ['result_type', 'shares_memory'],
#    'classes': ['TooHardError'],
#    'functions': ['linspace', 'logspace'],
#    'modules': ['_nx'],
#    'nofta': ['MAY_SHARE_BOUNDS',
#              'NaN',
#              '__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              'absolute_import',
#              'division',
#              'print_function']}),
#  ('numpy.core.getlimits',
#   {'builtins': ['array'],
#    'classes': ['MachAr', 'finfo', 'iinfo'],
#    'functions': ['_frz'],
#    'modules': ['ntypes', 'numeric'],
#    'nofta': ['__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              '_convert_to_float',
#              'absolute_import',
#              'division',
#              'print_function']}),
#  ('numpy.core.getlimits.ntypes', 'Uninspectable'),
#  ('numpy.core.getlimits.numeric', 'Uninspectable'),
#  ('numpy.core.info',
#   {'builtins': [],
#    'classes': [],
#    'functions': [],
#    'modules': [],
#    'nofta': ['__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              'absolute_import',
#              'depends',
#              'division',
#              'global_symbols',
#              'print_function']}),
#  ('numpy.core.machar',
#   {'builtins': [],
#    'classes': ['MachAr', 'errstate'],
#    'functions': ['any'],
#    'modules': [],
#    'nofta': ['__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              'absolute_import',
#              'division',
#              'print_function']}),
#  ('numpy.core.multiarray',
#   {'builtins': ['_fastCopyAndTranspose',
#                 '_get_ndarray_c_version',
#                 '_insert',
#                 '_reconstruct',
#                 '_vec_string',
#                 'add_docstring',
#                 'arange',
#                 'array',
#                 'bincount',
#                 'busday_count',
#                 'busday_offset',
#                 'can_cast',
#                 'compare_chararrays',
#                 'concatenate',
#                 'copyto',
#                 'correlate',
#                 'correlate2',
#                 'count_nonzero',
#                 'datetime_as_string',
#                 'datetime_data',
#                 'digitize',
#                 'dot',
#                 'einsum',
#                 'empty',
#                 'empty_like',
#                 'format_longfloat',
#                 'frombuffer',
#                 'fromfile',
#                 'fromiter',
#                 'fromstring',
#                 'getbuffer',
#                 'inner',
#                 'int_asbuffer',
#                 'interp',
#                 'is_busday',
#                 'lexsort',
#                 'matmul',
#                 'may_share_memory',
#                 'min_scalar_type',
#                 'nested_iters',
#                 'newbuffer',
#                 'packbits',
#                 'promote_types',
#                 'putmask',
#                 'ravel_multi_index',
#                 'result_type',
#                 'scalar',
#                 'set_datetimeparse_function',
#                 'set_numeric_ops',
#                 'set_string_function',
#                 'set_typeDict',
#                 'shares_memory',
#                 'test_interrupt',
#                 'unpackbits',
#                 'unravel_index',
#                 'vdot',
#                 'where',
#                 'zeros'],
#    'classes': ['broadcast',
#                'busdaycalendar',
#                'dtype',
#                'error',
#                'flagsobj',
#                'flatiter',
#                'ndarray',
#                'nditer'],
#    'functions': [],
#    'modules': [],
#    'nofta': ['ALLOW_THREADS',
#              'BUFSIZE',
#              'CLIP',
#              'DATETIMEUNITS',
#              'ITEM_HASOBJECT',
#              'ITEM_IS_POINTER',
#              'LIST_PICKLE',
#              'MAXDIMS',
#              'MAY_SHARE_BOUNDS',
#              'MAY_SHARE_EXACT',
#              'NEEDS_INIT',
#              'NEEDS_PYAPI',
#              'RAISE',
#              'USE_GETITEM',
#              'USE_SETITEM',
#              'WRAP',
#              '_ARRAY_API',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              '__version__',
#              '_flagdict',
#              'typeinfo']}),
#  ('numpy.core.numeric',
#   {'builtins': ['arange',
#                 'array',
#                 'busday_count',
#                 'busday_offset',
#                 'can_cast',
#                 'compare_chararrays',
#                 'concatenate',
#                 'copyto',
#                 'count_nonzero',
#                 'datetime_as_string',
#                 'datetime_data',
#                 'dot',
#                 'einsum',
#                 'empty',
#                 'empty_like',
#                 'fastCopyAndTranspose',
#                 'frombuffer',
#                 'fromfile',
#                 'fromiter',
#                 'frompyfunc',
#                 'fromstring',
#                 'getbuffer',
#                 'geterrobj',
#                 'inner',
#                 'int_asbuffer',
#                 'is_busday',
#                 'lexsort',
#                 'loads',
#                 'matmul',
#                 'may_share_memory',
#                 'min_scalar_type',
#                 'nested_iters',
#                 'newbuffer',
#                 'promote_types',
#                 'putmask',
#                 'result_type',
#                 'set_numeric_ops',
#                 'seterrobj',
#                 'shares_memory',
#                 'vdot',
#                 'where',
#                 'zeros'],
#    'classes': ['ComplexWarning',
#                'TooHardError',
#                '_unspecified',
#                'bool8',
#                'bool_',
#                'broadcast',
#                'busdaycalendar',
#                'byte',
#                'bytes_',
#                'cdouble',
#                'cfloat',
#                'character',
#                'clongdouble',
#                'clongfloat',
#                'complex128',
#                'complex256',
#                'complex64',
#                'complex_',
#                'complexfloating',
#                'csingle',
#                'datetime64',
#                'double',
#                'dtype',
#                'errstate',
#                'flatiter',
#                'flexible',
#                'float128',
#                'float16',
#                'float32',
#                'float64',
#                'float_',
#                'floating',
#                'generic',
#                'half',
#                'inexact',
#                'int0',
#                'int16',
#                'int32',
#                'int64',
#                'int8',
#                'int_',
#                'intc',
#                'integer',
#                'intp',
#                'longcomplex',
#                'longdouble',
#                'longfloat',
#                'longlong',
#                'ndarray',
#                'nditer',
#                'number',
#                'object0',
#                'object_',
#                'short',
#                'signedinteger',
#                'single',
#                'singlecomplex',
#                'str_',
#                'string0',
#                'string_',
#                'timedelta64',
#                'ubyte',
#                'ufunc',
#                'uint',
#                'uint0',
#                'uint16',
#                'uint32',
#                'uint64',
#                'uint8',
#                'uintc',
#                'uintp',
#                'ulonglong',
#                'unicode0',
#                'unicode_',
#                'unsignedinteger',
#                'ushort',
#                'void',
#                'void0'],
#    'functions': ['_maketup',
#                  '_mode_from_name',
#                  '_move_axis_to_0',
#                  '_setdef',
#                  '_validate_axis',
#                  'alen',
#                  'all',
#                  'allclose',
#                  'alltrue',
#                  'alterdot',
#                  'amax',
#                  'amin',
#                  'any',
#                  'argmax',
#                  'argmin',
#                  'argpartition',
#                  'argsort',
#                  'argwhere',
#                  'around',
#                  'array2string',
#                  'array_equal',
#                  'array_equiv',
#                  'array_repr',
#                  'array_str',
#                  'asanyarray',
#                  'asarray',
#                  'ascontiguousarray',
#                  'asfortranarray',
#                  'base_repr',
#                  'binary_repr',
#                  'choose',
#                  'clip',
#                  'compress',
#                  'convolve',
#                  'correlate',
#                  'cross',
#                  'cumprod',
#                  'cumproduct',
#                  'cumsum',
#                  'diagonal',
#                  'extend_all',
#                  'find_common_type',
#                  'flatnonzero',
#                  'fromfunction',
#                  'full',
#                  'full_like',
#                  'get_printoptions',
#                  'getbufsize',
#                  'geterr',
#                  'geterrcall',
#                  'identity',
#                  'indices',
#                  'isclose',
#                  'isfortran',
#                  'isscalar',
#                  'issctype',
#                  'issubdtype',
#                  'load',
#                  'maximum_sctype',
#                  'mean',
#                  'moveaxis',
#                  'ndim',
#                  'nonzero',
#                  'obj2sctype',
#                  'ones',
#                  'ones_like',
#                  'outer',
#                  'partition',
#                  'prod',
#                  'product',
#                  'ptp',
#                  'put',
#                  'rank',
#                  'ravel',
#                  'repeat',
#                  'require',
#                  'reshape',
#                  'resize',
#                  'restoredot',
#                  'roll',
#                  'rollaxis',
#                  'round_',
#                  'sctype2char',
#                  'searchsorted',
#                  'set_printoptions',
#                  'set_string_function',
#                  'setbufsize',
#                  'seterr',
#                  'seterrcall',
#                  'shape',
#                  'size',
#                  'sometrue',
#                  'sort',
#                  'squeeze',
#                  'std',
#                  'sum',
#                  'swapaxes',
#                  'take',
#                  'tensordot',
#                  'trace',
#                  'transpose',
#                  'var',
#                  'zeros_like'],
#    'modules': ['builtins',
#                'collections',
#                'fromnumeric',
#                'multiarray',
#                'numerictypes',
#                'operator',
#                'pickle',
#                'sys',
#                'umath',
#                'warnings'],
#    'nofta': ['ALLOW_THREADS',
#              'BUFSIZE',
#              'CLIP',
#              'ERR_CALL',
#              'ERR_DEFAULT',
#              'ERR_IGNORE',
#              'ERR_LOG',
#              'ERR_PRINT',
#              'ERR_RAISE',
#              'ERR_WARN',
#              'FLOATING_POINT_SUPPORT',
#              'FPE_DIVIDEBYZERO',
#              'FPE_INVALID',
#              'FPE_OVERFLOW',
#              'FPE_UNDERFLOW',
#              'False_',
#              'Inf',
#              'Infinity',
#              'MAXDIMS',
#              'MAY_SHARE_BOUNDS',
#              'MAY_SHARE_EXACT',
#              'NAN',
#              'NINF',
#              'NZERO',
#              'NaN',
#              'PINF',
#              'PZERO',
#              'RAISE',
#              'SHIFT_DIVIDEBYZERO',
#              'SHIFT_INVALID',
#              'SHIFT_OVERFLOW',
#              'SHIFT_UNDERFLOW',
#              'ScalarType',
#              'True_',
#              'UFUNC_BUFSIZE_DEFAULT',
#              'UFUNC_PYVALS_NAME',
#              'WRAP',
#              '_Unspecified',
#              '__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              '_errdict',
#              '_errdict_rev',
#              '_lkup',
#              '_mode_from_name_dict',
#              '_typelessdata',
#              'absolute',
#              'absolute_import',
#              'add',
#              'arccos',
#              'arccosh',
#              'arcsin',
#              'arcsinh',
#              'arctan',
#              'arctan2',
#              'arctanh',
#              'bitwise_and',
#              'bitwise_not',
#              'bitwise_or',
#              'bitwise_xor',
#              'cast',
# ...
#              'hermedomain',
#              'hermeone',
#              'hermex',
#              'hermezero',
#              'print_function']}),
#  ('numpy.polynomial.hermite_e.la', 'Uninspectable'),
#  ('numpy.polynomial.hermite_e.np', 'Uninspectable'),
#  ('numpy.polynomial.hermite_e.pu', 'Uninspectable'),
#  ('numpy.polynomial.hermite_e.warnings', 'Uninspectable'),
#  ('numpy.polynomial.laguerre',
#   {'builtins': [],
#    'classes': ['ABCPolyBase', 'Laguerre'],
#    'functions': ['lag2poly',
#                  'lagadd',
#                  'lagcompanion',
#                  'lagder',
#                  'lagdiv',
#                  'lagfit',
#                  'lagfromroots',
#                  'laggauss',
#                  'laggrid2d',
#                  'laggrid3d',
#                  'lagint',
#                  'lagline',
#                  'lagmul',
#                  'lagmulx',
#                  'lagpow',
#                  'lagroots',
#                  'lagsub',
#                  'lagtrim',
#                  'lagval',
#                  'lagval2d',
#                  'lagval3d',
#                  'lagvander',
#                  'lagvander2d',
#                  'lagvander3d',
#                  'lagweight',
#                  'poly2lag'],
#    'modules': ['la', 'np', 'pu', 'warnings'],
#    'nofta': ['__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              'absolute_import',
#              'division',
#              'lagdomain',
#              'lagone',
#              'lagx',
#              'lagzero',
#              'print_function']}),
#  ('numpy.polynomial.laguerre.la', 'Uninspectable'),
#  ('numpy.polynomial.laguerre.np', 'Uninspectable'),
#  ('numpy.polynomial.laguerre.pu', 'Uninspectable'),
#  ('numpy.polynomial.laguerre.warnings', 'Uninspectable'),
#  ('numpy.polynomial.legendre',
#   {'builtins': [],
#    'classes': ['ABCPolyBase', 'Legendre'],
#    'functions': ['leg2poly',
#                  'legadd',
#                  'legcompanion',
#                  'legder',
#                  'legdiv',
#                  'legfit',
#                  'legfromroots',
#                  'leggauss',
#                  'leggrid2d',
#                  'leggrid3d',
#                  'legint',
#                  'legline',
#                  'legmul',
#                  'legmulx',
#                  'legpow',
#                  'legroots',
#                  'legsub',
#                  'legtrim',
#                  'legval',
#                  'legval2d',
#                  'legval3d',
#                  'legvander',
#                  'legvander2d',
#                  'legvander3d',
#                  'legweight',
#                  'poly2leg'],
#    'modules': ['la', 'np', 'pu', 'warnings'],
#    'nofta': ['__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              'absolute_import',
#              'division',
#              'legdomain',
#              'legone',
#              'legx',
#              'legzero',
#              'print_function']}),
#  ('numpy.polynomial.legendre.la', 'Uninspectable'),
#  ('numpy.polynomial.legendre.np', 'Uninspectable'),
#  ('numpy.polynomial.legendre.pu', 'Uninspectable'),
#  ('numpy.polynomial.legendre.warnings', 'Uninspectable'),
#  ('numpy.polynomial.polynomial',
#   {'builtins': [],
#    'classes': ['ABCPolyBase', 'Polynomial'],
#    'functions': ['polyadd',
#                  'polycompanion',
#                  'polyder',
#                  'polydiv',
#                  'polyfit',
#                  'polyfromroots',
#                  'polygrid2d',
#                  'polygrid3d',
#                  'polyint',
#                  'polyline',
#                  'polymul',
#                  'polymulx',
#                  'polypow',
#                  'polyroots',
#                  'polysub',
#                  'polytrim',
#                  'polyval',
#                  'polyval2d',
#                  'polyval3d',
#                  'polyvander',
#                  'polyvander2d',
#                  'polyvander3d'],
#    'modules': ['la', 'np', 'pu', 'warnings'],
#    'nofta': ['__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              'absolute_import',
#              'division',
#              'polydomain',
#              'polyone',
#              'polyx',
#              'polyzero',
#              'print_function']}),
#  ('numpy.polynomial.polynomial.la', 'Uninspectable'),
#  ('numpy.polynomial.polynomial.np', 'Uninspectable'),
#  ('numpy.polynomial.polynomial.pu', 'Uninspectable'),
#  ('numpy.polynomial.polynomial.warnings', 'Uninspectable'),
#  ('numpy.polynomial.polyutils',
#   {'builtins': [],
#    'classes': ['PolyBase', 'PolyDomainError', 'PolyError', 'RankWarning'],
#    'functions': ['as_series',
#                  'getdomain',
#                  'mapdomain',
#                  'mapparms',
#                  'trimcoef',
#                  'trimseq'],
#    'modules': ['np'],
#    'nofta': ['__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              'absolute_import',
#              'division',
#              'print_function']}),
#  ('numpy.polynomial.polyutils.np', 'Uninspectable'),
#  ('numpy.random',
#   {'builtins': ['Lock',
#                 'beta',
#                 'binomial',
#                 'bytes',
#                 'chisquare',
#                 'choice',
#                 'dirichlet',
#                 'exponential',
#                 'f',
#                 'gamma',
#                 'geometric',
#                 'get_state',
#                 'gumbel',
#                 'hypergeometric',
#                 'laplace',
#                 'logistic',
#                 'lognormal',
#                 'logseries',
#                 'multinomial',
#                 'multivariate_normal',
#                 'negative_binomial',
#                 'noncentral_chisquare',
#                 'noncentral_f',
#                 'normal',
#                 'pareto',
#                 'permutation',
#                 'poisson',
#                 'power',
#                 'rand',
#                 'randint',
#                 'randn',
#                 'random',
#                 'random_integers',
#                 'random_sample',
#                 'ranf',
#                 'rayleigh',
#                 'sample',
#                 'seed',
#                 'set_state',
#                 'shuffle',
#                 'standard_cauchy',
#                 'standard_exponential',
#                 'standard_gamma',
#                 'standard_normal',
#                 'standard_t',
#                 'triangular',
#                 'uniform',
#                 'vonmises',
#                 'wald',
#                 'weibull',
#                 'zipf'],
#    'classes': ['RandomState'],
#    'functions': ['__RandomState_ctor', '_numpy_tester'],
#    'modules': ['info', 'mtrand', 'np', 'operator', 'warnings'],
#    'nofta': ['__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              '__path__',
#              '__warningregistry__',
#              'absolute_import',
#              'bench',
#              'division',
#              'print_function',
#              'test']}),
#  ('numpy.random.info',
#   {'builtins': [],
#    'classes': [],
#    'functions': [],
#    'modules': [],
#    'nofta': ['__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              'absolute_import',
#              'depends',
#              'division',
#              'print_function']}),
#  ('numpy.random.mtrand',
#   {'builtins': ['Lock',
#                 '_rand_bool',
#                 '_rand_int16',
#                 '_rand_int32',
#                 '_rand_int64',
#                 '_rand_int8',
#                 '_rand_uint16',
#                 '_rand_uint32',
#                 '_rand_uint64',
#                 '_rand_uint8',
#                 '_shape_from_size',
#                 'beta',
#                 'binomial',
#                 'bytes',
#                 'chisquare',
#                 'choice',
#                 'dirichlet',
#                 'exponential',
#                 'f',
#                 'gamma',
#                 'geometric',
#                 'get_state',
#                 'gumbel',
#                 'hypergeometric',
#                 'laplace',
#                 'logistic',
#                 'lognormal',
#                 'logseries',
#                 'multinomial',
#                 'multivariate_normal',
#                 'negative_binomial',
#                 'noncentral_chisquare',
#                 'noncentral_f',
#                 'normal',
#                 'pareto',
#                 'permutation',
#                 'poisson',
#                 'power',
#                 'rand',
#                 'randint',
#                 'randn',
#                 'random_integers',
#                 'random_sample',
#                 'rayleigh',
#                 'seed',
#                 'set_state',
#                 'shuffle',
#                 'standard_cauchy',
#                 'standard_exponential',
#                 'standard_gamma',
#                 'standard_normal',
#                 'standard_t',
#                 'triangular',
#                 'uniform',
#                 'vonmises',
#                 'wald',
#                 'weibull',
#                 'zipf'],
#    'classes': ['RandomState'],
#    'functions': [],
#    'modules': ['__builtins__', 'np', 'operator', 'warnings'],
#    'nofta': ['__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              '__test__',
#              '_rand',
#              '_randint_type']}),
#  ('numpy.random.mtrand.np', 'Uninspectable'),
#  ('numpy.random.mtrand.operator', 'Uninspectable'),
#  ('numpy.random.mtrand.warnings', 'Uninspectable'),
#  ('numpy.random.np', 'Uninspectable'),
#  ('numpy.random.operator', 'Uninspectable'),
#  ('numpy.random.warnings', 'Uninspectable'),
#  ('numpy.rec', 'Uninspectable'),
#  ('numpy.testing',
#   {'builtins': [],
#    'classes': ['IgnoreException',
#                'KnownFailureException',
#                'SkipTest',
#                'TestCase',
#                'Tester',
#                'clear_and_catch_warnings'],
#    'functions': ['assert_',
#                  'assert_allclose',
#                  'assert_almost_equal',
#                  'assert_approx_equal',
#                  'assert_array_almost_equal',
#                  'assert_array_almost_equal_nulp',
#                  'assert_array_equal',
#                  'assert_array_less',
#                  'assert_array_max_ulp',
#                  'assert_equal',
#                  'assert_no_warnings',
#                  'assert_raises',
#                  'assert_raises_regex',
#                  'assert_string_equal',
#                  'assert_warns',
#                  'build_err_msg',
#                  'decorate_methods',
#                  'jiffies',
#                  'measure',
#                  'memusage',
#                  'print_assert_equal',
#                  'raises',
#                  'rand',
#                  'run_module_suite',
#                  'rundocs',
#                  'runstring',
#                  'tempdir',
#                  'temppath'],
#    'modules': ['dec', 'decorators', 'nosetester', 'utils'],
#    'nofta': ['__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              '__path__',
#              'absolute_import',
#              'division',
#              'print_function',
#              'test',
#              'verbose']}),
#  ('numpy.testing.dec', 'Uninspectable'),
#  ('numpy.testing.decorators',
#   {'builtins': [],
#    'classes': ['SkipTest'],
#    'functions': ['deprecated',
#                  'knownfailureif',
#                  'setastest',
#                  'skipif',
#                  'slow'],
#    'modules': ['collections', 'warnings'],
#    'nofta': ['__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              'absolute_import',
#              'division',
#              'print_function']}),
#  ('numpy.testing.decorators.collections', 'Uninspectable'),
#  ('numpy.testing.decorators.warnings', 'Uninspectable'),
#  ('numpy.testing.nosetester',
#   {'builtins': [],
#    'classes': ['NoseTester', 'basestring'],
#    'functions': ['_numpy_tester',
#                  'get_package_name',
#                  'import_nose',
#                  'run_module_suite'],
#    'modules': ['np', 'os', 'sys', 'warnings'],
#    'nofta': ['__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              'absolute_import',
#              'division',
#              'print_function']}),
#  ('numpy.testing.nosetester.np', 'Uninspectable'),
#  ('numpy.testing.nosetester.os', 'Uninspectable'),
#  ('numpy.testing.nosetester.sys', 'Uninspectable'),
#  ('numpy.testing.nosetester.warnings', 'Uninspectable'),
#  ('numpy.testing.utils',
#   {'builtins': ['arange', 'empty'],
#    'classes': ['IgnoreException',
#                'KnownFailureException',
#                'KnownFailureTest',
#                'SkipTest',
#                'StringIO',
#                'WarningManager',
#                'WarningMessage',
#                'clear_and_catch_warnings',
#                'float32',
#                'ndarray',
#                'partial'],
#    'functions': ['_assert_no_warnings_context',
#                  '_assert_valid_refcount',
#                  '_assert_warns_context',
#                  '_gen_alignment_data',
#                  '_integer_repr',
#                  'array_repr',
#                  'assert_',
#                  'assert_allclose',
#                  'assert_almost_equal',
#                  'assert_approx_equal',
#                  'assert_array_almost_equal',
#                  'assert_array_almost_equal_nulp',
#                  'assert_array_compare',
#                  'assert_array_equal',
#                  'assert_array_less',
#                  'assert_array_max_ulp',
#                  'assert_equal',
#                  'assert_no_warnings',
#                  'assert_raises',
#                  'assert_raises_regex',
#                  'assert_string_equal',
#                  'assert_warns',
#                  'build_err_msg',
#                  'decorate_methods',
#                  'deprecate',
#                  'gisfinite',
#                  'gisinf',
#                  'gisnan',
#                  'import_nose',
#                  'integer_repr',
#                  'jiffies',
#                  'measure',
#                  'memusage',
#                  'mkdtemp',
#                  'mkstemp',
#                  'nulp_diff',
#                  'print_assert_equal',
#                  'raises',
#                  'rand',
#                  'rundocs',
#                  'runstring',
#                  'tempdir',
#                  'temppath'],
#    'modules': ['contextlib',
#                'operator',
#                'os',
#                're',
#                'shutil',
#                'sys',
#                'warnings'],
#    'nofta': ['__all__',
#              '__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              'absolute_import',
#              'assert_raises_regex_impl',
#              'division',
#              'print_function',
#              'verbose']}),
#  ('numpy.testing.utils.contextlib', 'Uninspectable'),
#  ('numpy.testing.utils.operator', 'Uninspectable'),
#  ('numpy.testing.utils.os', 'Uninspectable'),
#  ('numpy.testing.utils.re', 'Uninspectable'),
#  ('numpy.testing.utils.shutil', 'Uninspectable'),
#  ('numpy.testing.utils.sys', 'Uninspectable'),
#  ('numpy.testing.utils.warnings', 'Uninspectable'),
#  ('numpy.version',
#   {'builtins': [],
#    'classes': [],
#    'functions': [],
#    'modules': [],
#    'nofta': ['__builtins__',
#              '__doc__',
#              '__file__',
#              '__name__',
#              '__package__',
#              'full_version',
#              'git_revision',
#              'release',
#              'short_version',
#              'version']}),
#  ('numpy.warnings', 'Uninspectable')]

# %%
# And let's look at the module linkages
pprint.pprint(dep)
# Out:
# [('toolz', 'toolz.compatibility'),
#  ('toolz.compatibility', 'toolz.compatibility.operator'),
#  ('toolz.compatibility', 'toolz.compatibility.sys'),
#  ('toolz', 'toolz.dicttoolz'),
#  ('toolz.dicttoolz', 'toolz.dicttoolz.copy'),
#  ('toolz.dicttoolz', 'toolz.dicttoolz.operator'),
#  ('toolz', 'toolz.functoolz'),
#  ('toolz.functoolz', 'toolz.functoolz.inspect'),
#  ('toolz.functoolz', 'toolz.functoolz.operator'),
#  ('toolz', 'toolz.itertoolz'),
#  ('toolz.itertoolz', 'toolz.itertoolz.collections'),
#  ('toolz.itertoolz', 'toolz.itertoolz.heapq'),
#  ('toolz.itertoolz', 'toolz.itertoolz.itertools'),
#  ('toolz.itertoolz', 'toolz.itertoolz.operator'),
#  ('toolz', 'toolz.recipes'),
#  ('toolz.recipes', 'toolz.recipes.itertools'),
#  ('toolz', 'toolz.sandbox'),
#  ('toolz.sandbox', 'toolz.sandbox.core'),
#  ('toolz.sandbox', 'toolz.sandbox.parallel'),
#  ('toolz', 'toolz.utils')]
